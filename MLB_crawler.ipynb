# %%
# import packages
import requests
import json
import pandas as pd
from pyquery import PyQuery as pq  # PyQuery我其實沒用到哈哈哈

# %% [markdown]
# # 流程
# 1. 查看該網站network
# 2. 找出取得資料的xhr
# 3. 使用GET請求來取得資料（JSON格式）
# 4. 解析JSON
# 5. 展示所得到的球員資料
# 6. 將球員資料儲存成DataFrame

# %% [markdown]
# ## 爬蟲前置處理
# * 這邊由於這個網頁是動態生成的，因此我們不能直接用requests去要他，我們要用GET請求的方式去處理

# %%
session = requests.session()
# 設定請求訊息
session.header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'
                  'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'}

# %%
# 透過輸入的網址送出請求，並取得內容
def get_info(url):
    # 回傳的一般都是JSON格（字典）
    html = session.get(url)
    # 直接取出JSON格式
    return html.json()

# %% [markdown]
# ## 分別用以下兩url帶入可得到hitting和pitching的資料
# * hitting
#     * http://mlb.mlb.com/pubajax/wf/flow/stats.splayer?season=2019&sort_order=%27desc%27&sort_column=%27avg%27&stat_type=hitting&page_type=SortablePlayer&game_type=%27R%27&player_pool=QUALIFIER&season_type=ANY&sport_code=%27mlb%27&results=1000&recSP=1&recPP=200
# * pitching
#     * http://mlb.mlb.com/pubajax/wf/flow/stats.splayer?season=2019&sort_order=%27asc%27&sort_column=%27era%27&stat_type=pitching&page_type=SortablePlayer&game_type=%27R%27&player_pool=QUALIFIER&season_type=ANY&sport_code=%27mlb%27&results=1000&position=%271%27&recSP=1&recPP=100

# %%
# 目前是打者的資訊
doc_json = get_info("http://mlb.mlb.com/pubajax/wf/flow/stats.splayer?season=2019&sort_order=%27desc%27&sort_column=%27avg%27&stat_type=hitting&page_type=SortablePlayer&game_type=%27R%27&player_pool=QUALIFIER&season_type=ANY&sport_code=%27mlb%27&results=1000&recSP=1&recPP=200")

# %%
# checkpoint
# 查看目前資料樣式
doc_json
# Out:
# {'stats_sortable_player': {'copyRight': ' Copyright 2019 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt  ',
#   'queryResults': {'recPP': '200',
#    'created': '2019-06-25T04:53:09',
#    'recSP': '1',
#    'totalP': '1',
#    'recs': '161',
#    'totalSize': '161',
#    'row': [{'gidp': '3',
#      'sac': '0',
#      'np': '1334',
#      'name_display_first_last': 'Cody Bellinger',
#      'pos': 'RF',
#      'rank': '1',
#      'tb': '190',
#      'team_brief': 'Dodgers',
#      'sport_id': '1',
#      'name_display_last_init': 'Bellinger, C',
#      'bb': '48',
#      'avg': '.349',
#      'slg': '.699',
#      'ops': '1.143',
#      'hbp': '1',
#      'team_abbrev': 'LAD',
#      'so': '49',
#      'league_id': '104',
#      'sf': '3',
#      'team': 'lan',
#      'league': 'NL',
#      'cs': '5',
#      'sb': '8',
#      'go_ao': '0.52',
#      'last_name': 'Bellinger',
#      'player_id': '641355',
#      'ibb': '10',
#      'player_qualifier': '324',
#      'team_id': '119',
#      'go': '45',
#      'hr': '25',
#      'minimum_qualifier': '245',
#      'gdp': '3',
#      'name_display_roster': 'Bellinger, Cody',
#      'qualifies': 'Y',
#      'rbi': '61',
#      'name_first': 'Cody',
#      'bats': 'L',
#      'xbh': '43',
#      'g': '76',
#      'd': '16',
#      'team_name': 'Los Angeles Dodgers',
#      'sport': 'MLB',
#      'tpa': '324',
#      'name_display_last_first': 'Bellinger, Cody',
#      'h': '95',
#      'obp': '.444',
#      't': '2',
#      'ao': '86',
#      'r': '61',
#      'ab': '272',
#      'name_last': 'Bellinger'},
#     {'gidp': '6',
#      'sac': '0',
#      'np': '1167',
#      'name_display_first_last': 'Christian Yelich',
#      'pos': 'RF',
#      'rank': '2',
#      'tb': '198',
#      'team_brief': 'Brewers',
#      'sport_id': '1',
#      'name_display_last_init': 'Yelich, C',
#      'bb': '42',
#      'avg': '.342',
#      'slg': '.744',
#      'ops': '1.179',
#      'hbp': '4',
#      'team_abbrev': 'MIL',
#      'so': '56',
#      'league_id': '104',
#      'sf': '3',
#      'team': 'mil',
#      'league': 'NL',
#      'cs': '1',
#      'sb': '17',
#      'go_ao': '1.14',
#      'last_name': 'Yelich',
#      'player_id': '592885',
#      'ibb': '12',
#      'player_qualifier': '315',
#      'team_id': '158',
#      'go': '65',
#      'hr': '29',
#      'minimum_qualifier': '242',
#      'gdp': '6',
#      'name_display_roster': 'Yelich, Christian',
#      'qualifies': 'Y',
#      'rbi': '63',
#      'name_first': 'Christian',
#      'bats': 'L',
#      'xbh': '47',
#      'g': '71',
#      'd': '16',
#      'team_name': 'Milwaukee Brewers',
#      'sport': 'MLB',
#      'tpa': '315',
#      'name_display_last_first': 'Yelich, Christian',
#      'h': '91',
#      'obp': '.435',
#      't': '2',
#      'ao': '57',
#      'r': '63',
#      'ab': '266',
#      'name_last': 'Yelich'},
#     {'gidp': '3',
#      'sac': '0',
#      'np': '956',
#      'name_display_first_last': 'Jeff McNeil',
#      'pos': 'LF',
#      'rank': '3',
#      'tb': '118',
#      'team_brief': 'Mets',
#      'sport_id': '1',
#      'name_display_last_init': 'McNeil, J',
#      'bb': '17',
#      'avg': '.339',
#      'slg': '.488',
#      'ops': '.891',
#      'hbp': '9',
#      'team_abbrev': 'NYM',
#      'so': '29',
#      'league_id': '104',
#      'sf': '0',
#      'team': 'nyn',
#      'league': 'NL',
#      'cs': '4',
#      'sb': '2',
#      'go_ao': '0.77',
#      'last_name': 'McNeil',
#      'player_id': '643446',
#      'ibb': '2',
#      'player_qualifier': '268',
#      'team_id': '121',
#      'go': '57',
#      'hr': '5',
#      'minimum_qualifier': '245',
#      'gdp': '3',
#      'name_display_roster': 'McNeil, Jeff',
#      'qualifies': 'Y',
#      'rbi': '27',
#      'name_first': 'Jeff',
#      'bats': 'L',
#      'xbh': '25',
#      'g': '65',
#      'd': '19',
#      'team_name': 'New York Mets',
#      'sport': 'MLB',
#      'tpa': '268',
#      'name_display_last_first': 'McNeil, Jeff',
#      'h': '82',
#      'obp': '.403',
#      't': '1',
#      'ao': '74',
#      'r': '32',
#      'ab': '242',
#      'name_last': 'McNeil'},
#     {'gidp': '5',
#      'sac': '1',
#      'np': '1173',
#      'name_display_first_last': 'DJ LeMahieu',
#      'pos': '2B',
#      'rank': '4',
#      'tb': '145',
#      'team_brief': 'Yankees',
#      'sport_id': '1',
#      'name_display_last_init': 'LeMahieu, D',
#      'bb': '23',
#      'avg': '.331',
#      'slg': '.495',
#      'ops': '.875',
#      'hbp': '2',
#      'team_abbrev': 'NYY',
#      'so': '44',
#      'league_id': '103',
#      'sf': '3',
#      'team': 'nya',
#      'league': 'AL',
#      'cs': '0',
#      'sb': '4',
#      'go_ao': '1.20',
#      'last_name': 'LeMahieu',
#      'player_id': '518934',
#      'ibb': '0',
#      'player_qualifier': '322',
#      'team_id': '147',
#      'go': '85',
#      'hr': '10',
#      'minimum_qualifier': '242',
#      'gdp': '5',
#      'name_display_roster': 'LeMahieu, DJ',
#      'qualifies': 'Y',
#      'rbi': '51',
#      'name_first': 'DJ',
#      'bats': 'R',
#      'xbh': '27',
#      'g': '72',
#      'd': '16',
#      'team_name': 'New York Yankees',
#      'sport': 'MLB',
#      'tpa': '322',
#      'name_display_last_first': 'LeMahieu, DJ',
#      'h': '97',
#      'obp': '.380',
#      't': '1',
#      'ao': '71',
#      'r': '56',
#      'ab': '293',
#      'name_last': 'LeMahieu'},
#     {'gidp': '2',
#      'sac': '0',
#      'np': '1079',
#      'name_display_first_last': 'Charlie Blackmon',
#      'pos': 'RF',
#      'rank': '5',
#      'tb': '173',
#      'team_brief': 'Rockies',
#      'sport_id': '1',
#      'name_display_last_init': 'Blackmon, C',
#      'bb': '15',
#      'avg': '.331',
#      'slg': '.643',
#      'ops': '1.019',
#      'hbp': '5',
#      'team_abbrev': 'COL',
#      'so': '49',
#      'league_id': '104',
#      'sf': '1',
#      'team': 'col',
#      'league': 'NL',
#      'cs': '2',
#      'sb': '2',
#      'go_ao': '1.16',
#      'last_name': 'Blackmon',
#      'player_id': '453568',
#      'ibb': '0',
#      'player_qualifier': '290',
#      'team_id': '115',
#      'go': '71',
#      'hr': '18',
#      'minimum_qualifier': '239',
#      'gdp': '2',
#      'name_display_roster': 'Blackmon, Charlie',
#      'qualifies': 'Y',
#      'rbi': '49',
#      'name_first': 'Charlie',
#      'bats': 'L',
#      'xbh': '42',
#      'g': '61',
#      'd': '18',
#      'team_name': 'Colorado Rockies',
#      'sport': 'MLB',
#      'tpa': '290',
#      'name_display_last_first': 'Blackmon, Charlie',
#      'h': '89',
#      'obp': '.376',
#      't': '6',
#      'ao': '61',
#      'r': '54',
#      'ab': '269',
#      'name_last': 'Blackmon'},
#     {'gidp': '3',
#      'sac': '1',
#      'np': '1338',
#      'name_display_first_last': 'Jorge Polanco',
#      'pos': 'SS',
#      'rank': '6',
#      'tb': '163',
#      'team_brief': 'Twins',
#      'sport_id': '1',
#      'name_display_last_init': 'Polanco, J',
#      'bb': '28',
#      'avg': '.326',
#      'slg': '.542',
#      'ops': '.925',
#      'hbp': '2',
#      'team_abbrev': 'MIN',
#      'so': '48',
#      'league_id': '103',
#      'sf': '3',
#      'team': 'min',
#      'league': 'AL',
#      'cs': '3',
#      'sb': '2',
#      'go_ao': '0.36',
#      'last_name': 'Polanco',
#      'player_id': '593871',
#      'ibb': '2',
#      'player_qualifier': '335',
#      'team_id': '142',
#      'go': '42',
#      'hr': '11',
#      'minimum_qualifier': '239',
#      'gdp': '3',
#      'name_display_roster': 'Polanco, Jorge',
#      'qualifies': 'Y',
#      'rbi': '38',
#      'name_first': 'Jorge',
#      'bats': 'S',
#      'xbh': '38',
#      'g': '73',
#      'd': '22',
#      'team_name': 'Minnesota Twins',
#      'sport': 'MLB',
#      'tpa': '335',
#      'name_display_last_first': 'Polanco, Jorge',
#      'h': '98',
#      'obp': '.383',
#      't': '5',
#      'ao': '117',
#      'r': '48',
#      'ab': '301',
#      'name_last': 'Polanco'},
#     {'gidp': '3',
#      'sac': '0',
#      'np': '1182',
#      'name_display_first_last': 'Nolan Arenado',
#      'pos': '3B',
#      'rank': '7',
#      'tb': '174',
#      'team_brief': 'Rockies',
#      'sport_id': '1',
#      'name_display_last_init': 'Arenado, N',
#      'bb': '30',
#      'avg': '.324',
#      'slg': '.588',
#      'ops': '.973',
#      'hbp': '2',
#      'team_abbrev': 'COL',
#      'so': '42',
#      'league_id': '104',
#      'sf': '4',
#      'team': 'col',
#      'league': 'NL',
#      'cs': '2',
#      'sb': '2',
#      'go_ao': '0.71',
#      'last_name': 'Arenado',
#      'player_id': '571448',
#      'ibb': '6',
#      'player_qualifier': '332',
#      'team_id': '115',
#      'go': '67',
#      'hr': '19',
#      'minimum_qualifier': '239',
#      'gdp': '3',
#      'name_display_roster': 'Arenado, Nolan',
#      'qualifies': 'Y',
#      'rbi': '62',
#      'name_first': 'Nolan',
#      'bats': 'R',
#      'xbh': '38',
#      'g': '76',
#      'd': '17',
#      'team_name': 'Colorado Rockies',
#      'sport': 'MLB',
#      'tpa': '332',
#      'name_display_last_first': 'Arenado, Nolan',
#      'h': '96',
#      'obp': '.386',
#      't': '2',
#      'ao': '95',
#      'r': '57',
#      'ab': '296',
#      'name_last': 'Arenado'},
#     {'gidp': '14',
#      'sac': '0',
#      'np': '1177',
#      'name_display_first_last': 'Michael Brantley',
#      'pos': 'LF',
#      'rank': '8',
#      'tb': '151',
#      'team_brief': 'Astros',
#      'sport_id': '1',
#      'name_display_last_init': 'Brantley, M',
#      'bb': '26',
#      'avg': '.322',
#      'slg': '.512',
#      'ops': '.893',
#      'hbp': '3',
#      'team_abbrev': 'HOU',
#      'so': '30',
#      'league_id': '103',
#      'sf': '1',
#      'team': 'hou',
#      'league': 'AL',
#      'cs': '2',
#      'sb': '3',
#      'go_ao': '1.14',
#      'last_name': 'Brantley',
#      'player_id': '488726',
#      'ibb': '2',
#      'player_qualifier': '325',
#      'team_id': '117',
#      'go': '91',
#      'hr': '11',
#      'minimum_qualifier': '245',
#      'gdp': '14',
#      'name_display_roster': 'Brantley, Michael',
#      'qualifies': 'Y',
#      'rbi': '43',
#      'name_first': 'Michael',
#      'bats': 'L',
#      'xbh': '33',
#      'g': '75',
#      'd': '21',
#      'team_name': 'Houston Astros',
#      'sport': 'MLB',
#      'tpa': '325',
#      'name_display_last_first': 'Brantley, Michael',
#      'h': '95',
#      'obp': '.382',
#      't': '1',
#      'ao': '80',
#      'r': '38',
#      'ab': '295',
#      'name_last': 'Brantley'},
#     {'gidp': '3',
#      'sac': '1',
#      'np': '1090',
#      'name_display_first_last': 'David Dahl',
#      'pos': 'LF',
#      'rank': '9',
#      'tb': '133',
#      'team_brief': 'Rockies',
#      'sport_id': '1',
#      'name_display_last_init': 'Dahl, D',
#      'bb': '20',
#      'avg': '.319',
#      'slg': '.524',
#      'ops': '.894',
#      'hbp': '3',
#      'team_abbrev': 'COL',
#      'so': '71',
#      'league_id': '104',
#      'sf': '4',
#      'team': 'col',
#      'league': 'NL',
#      'cs': '4',
#      'sb': '2',
#      'go_ao': '1.43',
#      'last_name': 'Dahl',
#      'player_id': '621311',
#      'ibb': '0',
#      'player_qualifier': '282',
#      'team_id': '115',
#      'go': '63',
#      'hr': '8',
#      'minimum_qualifier': '239',
#      'gdp': '3',
#      'name_display_roster': 'Dahl, David',
#      'qualifies': 'Y',
#      'rbi': '37',
#      'name_first': 'David',
#      'bats': 'L',
#      'xbh': '32',
#      'g': '68',
#      'd': '20',
#      'team_name': 'Colorado Rockies',
#      'sport': 'MLB',
#      'tpa': '282',
#      'name_display_last_first': 'Dahl, David',
#      'h': '81',
#      'obp': '.370',
#      't': '4',
#      'ao': '44',
#      'r': '47',
#      'ab': '254',
#      'name_last': 'Dahl'},
#     {'gidp': '4',
#      'sac': '0',
#      'np': '1364',
#      'name_display_first_last': 'Freddie Freeman',
#      'pos': '1B',
#      'rank': '10',
#      'tb': '185',
#      'team_brief': 'Braves',
#      'sport_id': '1',
#      'name_display_last_init': 'Freeman, F',
#      'bb': '41',
#      'avg': '.315',
#      'slg': '.601',
#      'ops': '1.003',
#      'hbp': '4',
#      'team_abbrev': 'ATL',
#      'so': '60',
#      'league_id': '104',
#      'sf': '0',
#      'team': 'atl',
#      'league': 'NL',
#      'cs': '2',
#      'sb': '1',
#      'go_ao': '0.84',
#      'last_name': 'Freeman',
#      'player_id': '518692',
#      'ibb': '3',
#      'player_qualifier': '353',
#      'team_id': '144',
#      'go': '69',
#      'hr': '21',
#      'minimum_qualifier': '245',
#      'gdp': '4',
#      'name_display_roster': 'Freeman, Freddie',
#      'qualifies': 'Y',
#      'rbi': '61',
#      'name_first': 'Freddie',
#      'bats': 'L',
#      'xbh': '44',
#      'g': '78',
#      'd': '21',
#      'team_name': 'Atlanta Braves',
#      'sport': 'MLB',
#      'tpa': '353',
#      'name_display_last_first': 'Freeman, Freddie',
#      'h': '97',
#      'obp': '.402',
#      't': '2',
#      'ao': '82',
#      'r': '59',
#      'ab': '308',
#      'name_last': 'Freeman'},
#     {'gidp': '6',
#      'sac': '0',
#      'np': '1262',
#      'name_display_first_last': 'Josh Bell',
#      'pos': '1B',
#      'rank': '11',
#      'tb': '185',
#      'team_brief': 'Pirates',
#      'sport_id': '1',
#      'name_display_last_init': 'Bell, J',
#      'bb': '34',
#      'avg': '.315',
#      'slg': '.640',
#      'ops': '1.026',
#      'hbp': '2',
#      'team_abbrev': 'PIT',
#      'so': '68',
#      'league_id': '104',
#      'sf': '4',
#      'team': 'pit',
#      'league': 'NL',
#      'cs': '1',
#      'sb': '0',
#      'go_ao': '1.20',
#      'last_name': 'Bell',
#      'player_id': '605137',
#      'ibb': '7',
#      'player_qualifier': '329',
#      'team_id': '134',
#      'go': '73',
#      'hr': '20',
#      'minimum_qualifier': '236',
#      'gdp': '6',
#      'name_display_roster': 'Bell, Josh',
#      'qualifies': 'Y',
#      'rbi': '66',
#      'name_first': 'Josh',
#      'bats': 'S',
#      'xbh': '51',
#      'g': '75',
#      'd': '28',
#      'team_name': 'Pittsburgh Pirates',
#      'sport': 'MLB',
#      'tpa': '329',
#      'name_display_last_first': 'Bell, Josh',
#      'h': '91',
#      'obp': '.386',
#      't': '3',
#      'ao': '61',
#      'r': '57',
#      'ab': '289',
#      'name_last': 'Bell'},
#     {'gidp': '6',
#      'sac': '0',
#      'np': '946',
#      'name_display_first_last': 'Tim Anderson',
#      'pos': 'SS',
#      'rank': '12',
#      'tb': '130',
#      'team_brief': 'White Sox',
#      'sport_id': '1',
#      'name_display_last_init': 'Anderson, T',
#      'bb': '7',
#      'avg': '.313',
#      'slg': '.485',
#      'ops': '.823',
#      'hbp': '3',
#      'team_abbrev': 'CWS',
#      'so': '58',
#      'league_id': '103',
#      'sf': '0',
#      'team': 'cha',
#      'league': 'AL',
#      'cs': '4',
#      'sb': '15',
#      'go_ao': '1.33',
#      'last_name': 'Anderson',
#      'player_id': '641313',
#      'ibb': '0',
#      'player_qualifier': '278',
#      'team_id': '145',
#      'go': '72',
#      'hr': '11',
#      'minimum_qualifier': '236',
#      'gdp': '6',
#      'name_display_roster': 'Anderson, Tim',
#      'qualifies': 'Y',
#      'rbi': '37',
#      'name_first': 'Tim',
#      'bats': 'R',
#      'xbh': '24',
#      'g': '69',
#      'd': '13',
#      'team_name': 'Chicago White Sox',
#      'sport': 'MLB',
#      'tpa': '278',
#      'name_display_last_first': 'Anderson, Tim',
#      'h': '84',
#      'obp': '.338',
#      't': '0',
#      'ao': '54',
#      'r': '38',
#      'ab': '268',
#      'name_last': 'Anderson'},
#     {'gidp': '8',
#      'sac': '0',
#      'np': '1089',
#      'name_display_first_last': 'Anthony Rendon',
#      'pos': '3B',
#      'rank': '13',
#      'tb': '147',
#      'team_brief': 'Nationals',
#      'sport_id': '1',
#      'name_display_last_init': 'Rendon, A',
#      'bb': '32',
#      'avg': '.310',
#      'slg': '.634',
#      'ops': '1.038',
#      'hbp': '6',
#      'team_abbrev': 'WSH',
#      'so': '43',
#      'league_id': '104',
#      'sf': '2',
#      'team': 'was',
#      'league': 'NL',
#      'cs': '0',
#      'sb': '1',
#      'go_ao': '0.61',
#      'last_name': 'Rendon',
#      'player_id': '543685',
#      'ibb': '4',
#      'player_qualifier': '272',
#      'team_id': '120',
#      'go': '45',
#      'hr': '17',
#      'minimum_qualifier': '239',
#      'gdp': '8',
#      'name_display_roster': 'Rendon, Anthony',
#      'qualifies': 'Y',
#      'rbi': '53',
#      'name_first': 'Anthony',
#      'bats': 'R',
#      'xbh': '39',
#      'g': '63',
#      'd': '20',
#      'team_name': 'Washington Nationals',
#      'sport': 'MLB',
#      'tpa': '272',
#      'name_display_last_first': 'Rendon, Anthony',
#      'h': '72',
#      'obp': '.404',
#      't': '2',
#      'ao': '74',
#      'r': '57',
#      'ab': '232',
#      'name_last': 'Rendon'},
#     {'gidp': '4',
#      'sac': '0',
#      'np': '1259',
#      'name_display_first_last': 'Ketel Marte',
#      'pos': '2B',
#      'rank': '14',
#      'tb': '180',
#      'team_brief': 'D-backs',
#      'sport_id': '1',
#      'name_display_last_init': 'Marte, K',
#      'bb': '23',
#      'avg': '.309',
#      'slg': '.586',
#      'ops': '.946',
#      'hbp': '2',
#      'team_abbrev': 'ARI',
#      'so': '50',
#      'league_id': '104',
#      'sf': '2',
#      'team': 'ari',
#      'league': 'NL',
#      'cs': '0',
#      'sb': '4',
#      'go_ao': '0.98',
#      'last_name': 'Marte',
#      'player_id': '606466',
#      'ibb': '2',
#      'player_qualifier': '334',
#      'team_id': '109',
#      'go': '81',
#      'hr': '20',
#      'minimum_qualifier': '245',
#      'gdp': '4',
#      'name_display_roster': 'Marte, Ketel',
#      'qualifies': 'Y',
#      'rbi': '51',
#      'name_first': 'Ketel',
#      'bats': 'S',
#      'xbh': '41',
#      'g': '75',
#      'd': '17',
#      'team_name': 'Arizona Diamondbacks',
#      'sport': 'MLB',
#      'tpa': '334',
#      'name_display_last_first': 'Marte, Ketel',
#      'h': '95',
#      'obp': '.359',
#      't': '4',
#      'ao': '83',
#      'r': '51',
#      'ab': '307',
#      'name_last': 'Marte'},
#     {'gidp': '3',
#      'sac': '1',
#      'np': '1226',
#      'name_display_first_last': 'Rafael Devers',
#      'pos': '3B',
#      'rank': '15',
#      'tb': '152',
#      'team_brief': 'Red Sox',
#      'sport_id': '1',
#      'name_display_last_init': 'Devers, R',
#      'bb': '24',
#      'avg': '.308',
#      'slg': '.503',
#      'ops': '.865',
#      'hbp': '2',
#      'team_abbrev': 'BOS',
#      'so': '56',
#      'league_id': '103',
#      'sf': '1',
#      'team': 'bos',
#      'league': 'AL',
#      'cs': '5',
#      'sb': '8',
#      'go_ao': '1.28',
#      'last_name': 'Devers',
#      'player_id': '646240',
#      'ibb': '3',
#      'player_qualifier': '330',
#      'team_id': '111',
#      'go': '87',
#      'hr': '12',
#      'minimum_qualifier': '248',
#      'gdp': '3',
#      'name_display_roster': 'Devers, Rafael',
#      'qualifies': 'Y',
#      'rbi': '48',
#      'name_first': 'Rafael',
#      'bats': 'L',
#      'xbh': '33',
#      'g': '77',
#      'd': '19',
#      'team_name': 'Boston Red Sox',
#      'sport': 'MLB',
#      'tpa': '330',
#      'name_display_last_first': 'Devers, Rafael',
#      'h': '93',
#      'obp': '.362',
#      't': '2',
#      'ao': '68',
#      'r': '55',
#      'ab': '302',
#      'name_last': 'Devers'},
#     {'gidp': '4',
#      'sac': '0',
#      'np': '1376',
#      'name_display_first_last': 'Mike Trout',
#      'pos': 'CF',
#      'rank': '16',
#      'tb': '165',
#      'team_brief': 'Angels',
#      'sport_id': '1',
#      'name_display_last_init': 'Trout, M',
#      'bb': '68',
#      'avg': '.307',
#      'slg': '.642',
#      'ops': '1.108',
#      'hbp': '10',
#      'team_abbrev': 'LAA',
#      'so': '59',
#      'league_id': '103',
#      'sf': '2',
#      'team': 'ana',
#      'league': 'AL',
#      'cs': '2',
#      'sb': '8',
#      'go_ao': '0.59',
#      'last_name': 'Trout',
#      'player_id': '545361',
#      'ibb': '11',
#      'player_qualifier': '337',
#      'team_id': '108',
#      'go': '45',
#      'hr': '22',
#      'minimum_qualifier': '245',
#      'gdp': '4',
#      'name_display_roster': 'Trout, Mike',
#      'qualifies': 'Y',
#      'rbi': '56',
#      'name_first': 'Mike',
#      'bats': 'R',
#      'xbh': '41',
#      'g': '75',
#      'd': '18',
#      'team_name': 'Los Angeles Angels',
#      'sport': 'MLB',
#      'tpa': '337',
#      'name_display_last_first': 'Trout, Mike',
#      'h': '79',
#      'obp': '.466',
#      't': '1',
#      'ao': '76',
#      'r': '62',
#      'ab': '257',
#      'name_last': 'Trout'},
#     {'gidp': '4',
#      'sac': '0',
#      'np': '1208',
#      'name_display_first_last': 'Juan Soto',
#      'pos': 'LF',
#      'rank': '17',
#      'tb': '133',
#      'team_brief': 'Nationals',
#      'sport_id': '1',
#      'name_display_last_init': 'Soto, J',
#      'bb': '38',
#      'avg': '.305',
#      'slg': '.534',
#      'ops': '.933',
#      'hbp': '2',
#      'team_abbrev': 'WSH',
#      'so': '62',
#      'league_id': '104',
#      'sf': '2',
#      'team': 'was',
#      'league': 'NL',
#      'cs': '0',
#      'sb': '5',
#      'go_ao': '1.22',
#      'last_name': 'Soto',
#      'player_id': '665742',
#      'ibb': '1',
#      'player_qualifier': '291',
#      'team_id': '120',
#      'go': '62',
#      'hr': '12',
#      'minimum_qualifier': '239',
#      'gdp': '4',
#      'name_display_roster': 'Soto, Juan',
#      'qualifies': 'Y',
#      'rbi': '48',
#      'name_first': 'Juan',
#      'bats': 'L',
#      'xbh': '30',
#      'g': '67',
#      'd': '15',
#      'team_name': 'Washington Nationals',
#      'sport': 'MLB',
#      'tpa': '291',
#      'name_display_last_first': 'Soto, Juan',
#      'h': '76',
#      'obp': '.399',
#      't': '3',
#      'ao': '51',
#      'r': '45',
#      'ab': '249',
#      'name_last': 'Soto'},
#     {'gidp': '7',
#      'sac': '0',
#      'np': '1262',
#      'name_display_first_last': 'Trey Mancini',
#      'pos': 'RF',
#      'rank': '18',
#      'tb': '159',
#      'team_brief': 'Orioles',
#      'sport_id': '1',
#      'name_display_last_init': 'Mancini, T',
#      'bb': '25',
#      'avg': '.305',
#      'slg': '.564',
#      'ops': '.928',
#      'hbp': '3',
#      'team_abbrev': 'BAL',
#      'so': '61',
#      'league_id': '103',
#      'sf': '3',
#      'team': 'bal',
#      'league': 'AL',
#      'cs': '0',
#      'sb': '1',
#      'go_ao': '1.16',
#      'last_name': 'Mancini',
#      'player_id': '641820',
#      'ibb': '2',
#      'player_qualifier': '313',
#      'team_id': '110',
#      'go': '74',
#      'hr': '17',
#      'minimum_qualifier': '242',
#      'gdp': '7',
#      'name_display_roster': 'Mancini, Trey',
#      'qualifies': 'Y',
#      'rbi': '36',
#      'name_first': 'Trey',
#      'bats': 'R',
#      'xbh': '37',
#      'g': '73',
#      'd': '18',
#      'team_name': 'Baltimore Orioles',
#      'sport': 'MLB',
#      'tpa': '313',
#      'name_display_last_first': 'Mancini, Trey',
#      'h': '86',
#      'obp': '.364',
#      't': '2',
#      'ao': '64',
#      'r': '51',
#      'ab': '282',
#      'name_last': 'Mancini'},
#     {'gidp': '1',
#      'sac': '0',
#      'np': '1076',
#      'name_display_first_last': 'Austin Meadows',
#      'pos': 'RF',
#      'rank': '19',
#      'tb': '127',
#      'team_brief': 'Rays',
#      'sport_id': '1',
#      'name_display_last_init': 'Meadows, A',
#      'bb': '23',
#      'avg': '.304',
#      'slg': '.552',
#      'ops': '.930',
#      'hbp': '4',
#      'team_abbrev': 'TB',
#      'so': '61',
#      'league_id': '103',
#      'sf': '0',
#      'team': 'tba',
#      'league': 'AL',
#      'cs': '4',
#      'sb': '8',
#      'go_ao': '0.68',
#      'last_name': 'Meadows',
#      'player_id': '640457',
#      'ibb': '4',
#      'player_qualifier': '257',
#      'team_id': '139',
#      'go': '40',
#      'hr': '12',
#      'minimum_qualifier': '242',
#      'gdp': '1',
#      'name_display_roster': 'Meadows, Austin',
#      'qualifies': 'Y',
#      'rbi': '41',
#      'name_first': 'Austin',
#      'bats': 'L',
#      'xbh': '29',
#      'g': '60',
#      'd': '13',
#      'team_name': 'Tampa Bay Rays',
#      'sport': 'MLB',
#      'tpa': '257',
#      'name_display_last_first': 'Meadows, Austin',
#      'h': '70',
#      'obp': '.377',
#      't': '4',
#      'ao': '59',
#      'r': '33',
#      'ab': '230',
#      'name_last': 'Meadows'},
#     {'gidp': '11',
#      'sac': '0',
#      'np': '1166',
#      'name_display_first_last': 'Elvis Andrus',
#      'pos': 'SS',
#      'rank': '20',
#      'tb': '130',
#      'team_brief': 'Rangers',
#      'sport_id': '1',
#      'name_display_last_init': 'Andrus, E',
#      'bb': '13',
#      'avg': '.304',
#      'slg': '.464',
#      'ops': '.804',
#      'hbp': '4',
#      'team_abbrev': 'TEX',
#      'so': '49',
#      'league_id': '103',
#      'sf': '3',
#      'team': 'tex',
#      'league': 'AL',
#      'cs': '2',
#      'sb': '16',
#      'go_ao': '1.26',
#      'last_name': 'Andrus',
#      'player_id': '462101',
#      'ibb': '0',
#      'player_qualifier': '300',
#      'team_id': '140',
#      'go': '83',
#      'hr': '7',
#      'minimum_qualifier': '242',
#      'gdp': '11',
#      'name_display_roster': 'Andrus, Elvis',
#      'qualifies': 'Y',
#      'rbi': '43',
#      'name_first': 'Elvis',
#      'bats': 'R',
#      'xbh': '28',
#      'g': '67',
#      'd': '18',
#      'team_name': 'Texas Rangers',
#      'sport': 'MLB',
#      'tpa': '300',
#      'name_display_last_first': 'Andrus, Elvis',
#      'h': '85',
#      'obp': '.340',
#      't': '3',
#      'ao': '66',
#      'r': '44',
#      'ab': '280',
#      'name_last': 'Andrus'},
#     {'gidp': '4',
#      'sac': '0',
#      'np': '1351',
#      'name_display_first_last': 'Whit Merrifield',
#      'pos': '2B',
#      'rank': '21',
#      'tb': '167',
#      'team_brief': 'Royals',
#      'sport_id': '1',
#      'name_display_last_init': 'Merrifield, W',
#      'bb': '22',
#      'avg': '.303',
#      'slg': '.506',
#      'ops': '.856',
#      'hbp': '3',
#      'team_abbrev': 'KC',
#      'so': '62',
#      'league_id': '103',
#      'sf': '2',
#      'team': 'kca',
#      'league': 'AL',
#      'cs': '6',
#      'sb': '11',
#      'go_ao': '0.67',
#      'last_name': 'Merrifield',
#      'player_id': '593160',
#      'ibb': '3',
#      'player_qualifier': '357',
#      'team_id': '118',
#      'go': '68',
#      'hr': '11',
#      'minimum_qualifier': '245',
#      'gdp': '4',
#      'name_display_roster': 'Merrifield, Whit',
#      'qualifies': 'Y',
#      'rbi': '40',
#      'name_first': 'Whit',
#      'bats': 'R',
#      'xbh': '38',
#      'g': '79',
#      'd': '20',
#      'team_name': 'Kansas City Royals',
#      'sport': 'MLB',
#      'tpa': '357',
#      'name_display_last_first': 'Merrifield, Whit',
#      'h': '100',
#      'obp': '.350',
#      't': '7',
#      'ao': '102',
#      'r': '56',
#      'ab': '330',
#      'name_last': 'Merrifield'},
#     {'gidp': '4',
#      'sac': '0',
#      'np': '984',
#      'name_display_first_last': 'Alex Verdugo',
#      'pos': 'CF',
#      'rank': '22',
#      'tb': '110',
#      'team_brief': 'Dodgers',
#      'sport_id': '1',
#      'name_display_last_init': 'Verdugo, A',
#      'bb': '18',
#      'avg': '.302',
#      'slg': '.489',
#      'ops': '.841',
#      'hbp': '2',
#      'team_abbrev': 'LAD',
#      'so': '26',
#      'league_id': '104',
#      'sf': '5',
#      'team': 'lan',
#      'league': 'NL',
#      'cs': '0',
#      'sb': '3',
#      'go_ao': '1.09',
#      'last_name': 'Verdugo',
#      'player_id': '657077',
#      'ibb': '1',
#      'player_qualifier': '250',
#      'team_id': '119',
#      'go': '71',
#      'hr': '7',
#      'minimum_qualifier': '245',
#      'gdp': '4',
#      'name_display_roster': 'Verdugo, Alex',
#      'qualifies': 'Y',
#      'rbi': '32',
#      'name_first': 'Alex',
#      'bats': 'L',
#      'xbh': '26',
#      'g': '74',
#      'd': '17',
#      'team_name': 'Los Angeles Dodgers',
#      'sport': 'MLB',
#      'tpa': '250',
#      'name_display_last_first': 'Verdugo, Alex',
#      'h': '68',
#      'obp': '.352',
#      't': '2',
#      'ao': '65',
#      'r': '26',
#      'ab': '225',
#      'name_last': 'Verdugo'},
#     {'gidp': '8',
#      'sac': '0',
#      'np': '1149',
#      'name_display_first_last': 'Justin Turner',
#      'pos': '3B',
#      'rank': '23',
#      'tb': '110',
#      'team_brief': 'Dodgers',
#      'sport_id': '1',
#      'name_display_last_init': 'Turner, J',
#      'bb': '27',
#      'avg': '.300',
#      'slg': '.435',
#      'ops': '.815',
#      'hbp': '8',
#      'team_abbrev': 'LAD',
#      'so': '45',
#      'league_id': '104',
#      'sf': '4',
#      'team': 'lan',
#      'league': 'NL',
#      'cs': '0',
#      'sb': '1',
#      'go_ao': '0.56',
#      'last_name': 'Turner',
#      'player_id': '457759',
#      'ibb': '0',
#      'player_qualifier': '292',
#      'team_id': '119',
#      'go': '49',
#      'hr': '7',
#      'minimum_qualifier': '245',
#      'gdp': '8',
#      'name_display_roster': 'Turner, Justin',
#      'qualifies': 'Y',
#      'rbi': '30',
#      'name_first': 'Justin',
#      'bats': 'R',
#      'xbh': '20',
#      'g': '71',
#      'd': '13',
#      'team_name': 'Los Angeles Dodgers',
#      'sport': 'MLB',
#      'tpa': '292',
#      'name_display_last_first': 'Turner, Justin',
#      'h': '76',
#      'obp': '.380',
#      't': '0',
#      'ao': '87',
#      'r': '35',
#      'ab': '253',
#      'name_last': 'Turner'},
#     {'gidp': '1',
#      'sac': '1',
#      'np': '1163',
#      'name_display_first_last': 'Yoan Moncada',
#      'pos': '3B',
#      'rank': '24',
#      'tb': '143',
#      'team_brief': 'White Sox',
#      'sport_id': '1',
#      'name_display_last_init': 'Moncada, Y',
#      'bb': '21',
#      'avg': '.299',
#      'slg': '.522',
#      'ops': '.874',
#      'hbp': '2',
#      'team_abbrev': 'CWS',
#      'so': '83',
#      'league_id': '103',
#      'sf': '1',
#      'team': 'cha',
#      'league': 'AL',
#      'cs': '3',
#      'sb': '5',
#      'go_ao': '0.91',
#      'last_name': 'Moncada',
#      'player_id': '660162',
#      'ibb': '1',
#      'player_qualifier': '299',
#      'team_id': '145',
#      'go': '53',
#      'hr': '13',
#      'minimum_qualifier': '236',
#      'gdp': '1',
#      'name_display_roster': 'Moncada, Yoan',
#      'qualifies': 'Y',
#      'rbi': '42',
#      'name_first': 'Yoan',
#      'bats': 'S',
#      'xbh': '32',
#      'g': '70',
#      'd': '16',
#      'team_name': 'Chicago White Sox',
#      'sport': 'MLB',
#      'tpa': '299',
#      'name_display_last_first': 'Moncada, Yoan',
#      'h': '82',
#      'obp': '.352',
#      't': '3',
#      'ao': '58',
#      'r': '42',
#      'ab': '274',
#      'name_last': 'Moncada'},
#     {'gidp': '7',
#      'sac': '0',
#      'np': '1070',
#      'name_display_first_last': 'Tommy La Stella',
#      'pos': '2B',
#      'rank': '25',
#      'tb': '129',
#      'team_brief': 'Angels',
#      'sport_id': '1',
#      'name_display_last_init': 'La Stella, T',
#      'bb': '18',
#      'avg': '.297',
#      'slg': '.498',
#      'ops': '.848',
#      'hbp': '3',
#      'team_abbrev': 'LAA',
#      'so': '26',
#      'league_id': '103',
#      'sf': '0',
#      'team': 'ana',
#      'league': 'AL',
#      'cs': '0',
#      'sb': '0',
#      'go_ao': '1.14',
#      'last_name': 'La Stella',
#      'player_id': '600303',
#      'ibb': '0',
#      'player_qualifier': '286',
#      'team_id': '108',
#      'go': '83',
#      'hr': '15',
#      'minimum_qualifier': '245',
#      'gdp': '7',
#      'name_display_roster': 'La Stella, Tommy',
#      'qualifies': 'Y',
#      'rbi': '43',
#      'name_first': 'Tommy',
#      'bats': 'L',
#      'xbh': '22',
#      'g': '72',
#      'd': '7',
#      'team_name': 'Los Angeles Angels',
#      'sport': 'MLB',
#      'tpa': '286',
#      'name_display_last_first': 'La Stella, Tommy',
#      'h': '77',
#      'obp': '.350',
#      't': '0',
#      'ao': '73',
#      'r': '46',
#      'ab': '259',
#      'name_last': 'La Stella'},
#     {'gidp': '6',
#      'sac': '0',
#      'np': '1011',
#      'name_display_first_last': 'Josh Reddick',
#      'pos': 'RF',
#      'rank': '26',
#      'tb': '116',
#      'team_brief': 'Astros',
#      'sport_id': '1',
#      'name_display_last_init': 'Reddick, J',
#      'bb': '19',
#      'avg': '.297',
#      'slg': '.441',
#      'ops': '.778',
#      'hbp': '0',
#      'team_abbrev': 'HOU',
#      'so': '30',
#      'league_id': '103',
#      'sf': '6',
#      'team': 'hou',
#      'league': 'AL',
#      'cs': '2',
#      'sb': '4',
#      'go_ao': '0.66',
#      'last_name': 'Reddick',
#      'player_id': '502210',
#      'ibb': '1',
#      'player_qualifier': '289',
#      'team_id': '117',
#      'go': '64',
#      'hr': '9',
#      'minimum_qualifier': '245',
#      'gdp': '6',
#      'name_display_roster': 'Reddick, Josh',
#      'qualifies': 'Y',
#      'rbi': '28',
#      'name_first': 'Josh',
#      'bats': 'L',
#      'xbh': '19',
#      'g': '71',
#      'd': '9',
#      'team_name': 'Houston Astros',
#      'sport': 'MLB',
#      'tpa': '289',
#      'name_display_last_first': 'Reddick, Josh',
#      'h': '78',
#      'obp': '.337',
#      't': '1',
#      'ao': '97',
#      'r': '32',
#      'ab': '263',
#      'name_last': 'Reddick'},
#     {'gidp': '5',
#      'sac': '0',
#      'np': '1431',
#      'name_display_first_last': 'Xander Bogaerts',
#      'pos': 'SS',
#      'rank': '27',
#      'tb': '157',
#      'team_brief': 'Red Sox',
#      'sport_id': '1',
#      'name_display_last_init': 'Bogaerts, X',
#      'bb': '47',
#      'avg': '.296',
#      'slg': '.529',
#      'ops': '.917',
#      'hbp': '0',
#      'team_abbrev': 'BOS',
#      'so': '60',
#      'league_id': '103',
#      'sf': '4',
#      'team': 'bos',
#      'league': 'AL',
#      'cs': '1',
#      'sb': '3',
#      'go_ao': '0.91',
#      'last_name': 'Bogaerts',
#      'player_id': '593428',
#      'ibb': '2',
#      'player_qualifier': '348',
#      'team_id': '111',
#      'go': '73',
#      'hr': '14',
#      'minimum_qualifier': '248',
#      'gdp': '5',
#      'name_display_roster': 'Bogaerts, Xander',
#      'qualifies': 'Y',
#      'rbi': '51',
#      'name_first': 'Xander',
#      'bats': 'R',
#      'xbh': '41',
#      'g': '77',
#      'd': '27',
#      'team_name': 'Boston Red Sox',
#      'sport': 'MLB',
#      'tpa': '348',
#      'name_display_last_first': 'Bogaerts, Xander',
#      'h': '88',
#      'obp': '.388',
#      't': '0',
#      'ao': '80',
#      'r': '59',
#      'ab': '297',
#      'name_last': 'Bogaerts'},
#     {'gidp': '6',
#      'sac': '0',
#      'np': '1052',
#      'name_display_first_last': 'Miguel Cabrera',
#      'pos': '1B',
#      'rank': '28',
#      'tb': '96',
#      'team_brief': 'Tigers',
#      'sport_id': '1',
#      'name_display_last_init': 'Cabrera, M',
#      'bb': '24',
#      'avg': '.296',
#      'slg': '.389',
#      'ops': '.747',
#      'hbp': '2',
#      'team_abbrev': 'DET',
#      'so': '57',
#      'league_id': '103',
#      'sf': '3',
#      'team': 'det',
#      'league': 'AL',
#      'cs': '0',
#      'sb': '0',
#      'go_ao': '1.00',
#      'last_name': 'Cabrera',
#      'player_id': '408234',
#      'ibb': '2',
#      'player_qualifier': '276',
#      'team_id': '116',
#      'go': '60',
#      'hr': '4',
#      'minimum_qualifier': '229',
#      'gdp': '6',
#      'name_display_roster': 'Cabrera, Miguel',
#      'qualifies': 'Y',
#      'rbi': '30',
#      'name_first': 'Miguel',
#      'bats': 'R',
#      'xbh': '15',
#      'g': '69',
#      'd': '11',
#      'team_name': 'Detroit Tigers',
#      'sport': 'MLB',
#      'tpa': '276',
#      'name_display_last_first': 'Cabrera, Miguel',
#      'h': '73',
#      'obp': '.359',
#      't': '0',
#      'ao': '60',
#      'r': '17',
#      'ab': '247',
#      'name_last': 'Cabrera'},
#     {'gidp': '3',
#      'sac': '0',
#      'np': '1022',
#      'name_display_first_last': 'Willson Contreras',
#      'pos': 'C',
#      'rank': '29',
#      'tb': '124',
#      'team_brief': 'Cubs',
#      'sport_id': '1',
#      'name_display_last_init': 'Contreras, W',
#      'bb': '27',
#      'avg': '.294',
#      'slg': '.561',
#      'ops': '.949',
#      'hbp': '8',
#      'team_abbrev': 'CHC',
#      'so': '67',
#      'league_id': '104',
#      'sf': '2',
#      'team': 'chn',
#      'league': 'NL',
#      'cs': '2',
#      'sb': '1',
#      'go_ao': '1.46',
#      'last_name': 'Contreras',
#      'player_id': '575929',
#      'ibb': '2',
#      'player_qualifier': '258',
#      'team_id': '112',
#      'go': '54',
#      'hr': '16',
#      'minimum_qualifier': '242',
#      'gdp': '3',
#      'name_display_roster': 'Contreras, Willson',
#      'qualifies': 'Y',
#      'rbi': '45',
#      'name_first': 'Willson',
#      'bats': 'R',
#      'xbh': '27',
#      'g': '67',
#      'd': '11',
#      'team_name': 'Chicago Cubs',
#      'sport': 'MLB',
#      'tpa': '258',
#      'name_display_last_first': 'Contreras, Willson',
#      'h': '65',
#      'obp': '.388',
#      't': '0',
#      'ao': '37',
#      'r': '36',
#      'ab': '221',
#      'name_last': 'Contreras'},
#     {'gidp': '8',
#      'sac': '0',
#      'np': '915',
#      'name_display_first_last': 'Jose Iglesias',
#      'pos': 'SS',
#      'rank': '29',
#      'tb': '100',
#      'team_brief': 'Reds',
#      'sport_id': '1',
#      'name_display_last_init': 'Iglesias, J',
#      'bb': '13',
#      'avg': '.294',
#      'slg': '.420',
#      'ops': '.754',
#      'hbp': '1',
#      'team_abbrev': 'CIN',
#      'so': '38',
#      'league_id': '104',
#      'sf': '0',
#      'team': 'cin',
#      'league': 'NL',
#      'cs': '3',
#      'sb': '2',
#      'go_ao': '1.45',
#      'last_name': 'Iglesias',
#      'player_id': '578428',
#      'ibb': '3',
#      'player_qualifier': '252',
#      'team_id': '113',
#      'go': '77',
#      'hr': '5',
#      'minimum_qualifier': '236',
#      'gdp': '8',
#      'name_display_roster': 'Iglesias, Jose',
#      'qualifies': 'Y',
#      'rbi': '30',
#      'name_first': 'Jose',
#      'bats': 'R',
#      'xbh': '18',
#      'g': '69',
#      'd': '11',
#      'team_name': 'Cincinnati Reds',
#      'sport': 'MLB',
#      'tpa': '252',
#      'name_display_last_first': 'Iglesias, Jose',
#      'h': '70',
#      'obp': '.333',
#      't': '2',
#      'ao': '53',
#      'r': '31',
#      'ab': '238',
#      'name_last': 'Iglesias'},
#     {'gidp': '10',
#      'sac': '0',
#      'np': '1278',
#      'name_display_first_last': 'Tommy Pham',
#      'pos': 'LF',
#      'rank': '29',
#      'tb': '129',
#      'team_brief': 'Rays',
#      'sport_id': '1',
#      'name_display_last_init': 'Pham, T',
#      'bb': '46',
#      'avg': '.294',
#      'slg': '.474',
#      'ops': '.875',
#      'hbp': '3',
#      'team_abbrev': 'TB',
#      'so': '57',
#      'league_id': '103',
#      'sf': '1',
#      'team': 'tba',
#      'league': 'AL',
#      'cs': '3',
#      'sb': '7',
#      'go_ao': '1.67',
#      'last_name': 'Pham',
#      'player_id': '502054',
#      'ibb': '2',
#      'player_qualifier': '322',
#      'team_id': '139',
#      'go': '85',
#      'hr': '11',
#      'minimum_qualifier': '242',
#      'gdp': '10',
#      'name_display_roster': 'Pham, Tommy',
#      'qualifies': 'Y',
#      'rbi': '33',
#      'name_first': 'Tommy',
#      'bats': 'R',
#      'xbh': '25',
#      'g': '71',
#      'd': '12',
#      'team_name': 'Tampa Bay Rays',
#      'sport': 'MLB',
#      'tpa': '322',
#      'name_display_last_first': 'Pham, Tommy',
#      'h': '80',
#      'obp': '.401',
#      't': '2',
#      'ao': '51',
#      'r': '36',
#      'ab': '272',
#      'name_last': 'Pham'},
#     {'gidp': '1',
#      'sac': '0',
#      'np': '1348',
#      'name_display_first_last': 'Trevor Story',
#      'pos': 'SS',
#      'rank': '32',
#      'tb': '162',
#      'team_brief': 'Rockies',
#      'sport_id': '1',
#      'name_display_last_init': 'Story, T',
#      'bb': '27',
#      'avg': '.294',
#      'slg': '.547',
#      'ops': '.907',
#      'hbp': '4',
#      'team_abbrev': 'COL',
#      'so': '86',
#      'league_id': '104',
#      'sf': '1',
#      'team': 'col',
#      'league': 'NL',
#      'cs': '4',
#      'sb': '12',
#      'go_ao': '0.77',
#      'last_name': 'Story',
#      'player_id': '596115',
#      'ibb': '0',
#      'player_qualifier': '328',
#      'team_id': '115',
#      'go': '54',
#      'hr': '17',
#      'minimum_qualifier': '239',
#      'gdp': '1',
#      'name_display_roster': 'Story, Trevor',
#      'qualifies': 'Y',
#      'rbi': '48',
#      'name_first': 'Trevor',
#      'bats': 'R',
#      'xbh': '39',
#      'g': '72',
#      'd': '20',
#      'team_name': 'Colorado Rockies',
#      'sport': 'MLB',
#      'tpa': '328',
#      'name_display_last_first': 'Story, Trevor',
#      'h': '87',
#      'obp': '.360',
#      't': '2',
#      'ao': '70',
#      'r': '65',
#      'ab': '296',
#      'name_last': 'Story'},
#     {'gidp': '6',
#      'sac': '0',
#      'np': '1012',
#      'name_display_first_last': 'Avisail Garcia',
#      'pos': 'RF',
#      'rank': '33',
#      'tb': '125',
#      'team_brief': 'Rays',
#      'sport_id': '1',
#      'name_display_last_init': 'Garcia, A',
#      'bb': '18',
#      'avg': '.294',
#      'slg': '.477',
#      'ops': '.829',
#      'hbp': '6',
#      'team_abbrev': 'TB',
#      'so': '63',
#      'league_id': '103',
#      'sf': '1',
#      'team': 'tba',
#      'league': 'AL',
#      'cs': '2',
#      'sb': '8',
#      'go_ao': '1.02',
#      'last_name': 'Garcia',
#      'player_id': '541645',
#      'ibb': '2',
#      'player_qualifier': '287',
#      'team_id': '139',
#      'go': '62',
#      'hr': '11',
#      'minimum_qualifier': '242',
#      'gdp': '6',
#      'name_display_roster': 'Garcia, Avisail',
#      'qualifies': 'Y',
#      'rbi': '35',
#      'name_first': 'Avisail',
#      'bats': 'R',
#      'xbh': '25',
#      'g': '66',
#      'd': '13',
#      'team_name': 'Tampa Bay Rays',
#      'sport': 'MLB',
#      'tpa': '287',
#      'name_display_last_first': 'Garcia, Avisail',
#      'h': '77',
#      'obp': '.352',
#      't': '1',
#      'ao': '61',
#      'r': '36',
#      'ab': '262',
#      'name_last': 'Garcia'},
#     {'gidp': '5',
#      'sac': '0',
#      'np': '1158',
#      'name_display_first_last': 'David Fletcher',
#      'pos': '3B',
#      'rank': '34',
#      'tb': '108',
#      'team_brief': 'Angels',
#      'sport_id': '1',
#      'name_display_last_init': 'Fletcher, D',
#      'bb': '22',
#      'avg': '.293',
#      'slg': '.411',
#      'ops': '.757',
#      'hbp': '0',
#      'team_abbrev': 'LAA',
#      'so': '20',
#      'league_id': '103',
#      'sf': '1',
#      'team': 'ana',
#      'league': 'AL',
#      'cs': '3',
#      'sb': '5',
#      'go_ao': '1.04',
#      'last_name': 'Fletcher',
#      'player_id': '664058',
#      'ibb': '1',
#      'player_qualifier': '286',
#      'team_id': '108',
#      'go': '85',
#      'hr': '5',
#      'minimum_qualifier': '245',
#      'gdp': '5',
#      'name_display_roster': 'Fletcher, David',
#      'qualifies': 'Y',
#      'rbi': '29',
#      'name_first': 'David',
#      'bats': 'R',
#      'xbh': '19',
#      'g': '74',
#      'd': '12',
#      'team_name': 'Los Angeles Angels',
#      'sport': 'MLB',
#      'tpa': '286',
#      'name_display_last_first': 'Fletcher, David',
#      'h': '77',
#      'obp': '.346',
#      't': '2',
#      'ao': '82',
#      'r': '36',
#      'ab': '263',
#      'name_last': 'Fletcher'},
#     {'gidp': '9',
#      'sac': '0',
#      'np': '1373',
#      'name_display_first_last': 'Carlos Santana',
#      'pos': '1B',
#      'rank': '35',
#      'tb': '148',
#      'team_brief': 'Indians',
#      'sport_id': '1',
#      'name_display_last_init': 'Santana, C',
#      'bb': '56',
#      'avg': '.291',
#      'slg': '.538',
#      'ops': '.951',
#      'hbp': '1',
#      'team_abbrev': 'CLE',
#      'so': '52',
#      'league_id': '103',
#      'sf': '0',
#      'team': 'cle',
#      'league': 'AL',
#      'cs': '0',
#      'sb': '3',
#      'go_ao': '1.34',
#      'last_name': 'Santana',
#      'player_id': '467793',
#      'ibb': '6',
#      'player_qualifier': '332',
#      'team_id': '114',
#      'go': '82',
#      'hr': '17',
#      'minimum_qualifier': '242',
#      'gdp': '9',
#      'name_display_roster': 'Santana, Carlos',
#      'qualifies': 'Y',
#      'rbi': '47',
#      'name_first': 'Carlos',
#      'bats': 'S',
#      'xbh': '33',
#      'g': '77',
#      'd': '15',
#      'team_name': 'Cleveland Indians',
#      'sport': 'MLB',
#      'tpa': '332',
#      'name_display_last_first': 'Santana, Carlos',
#      'h': '80',
#      'obp': '.413',
#      't': '1',
#      'ao': '61',
#      'r': '54',
#      'ab': '275',
#      'name_last': 'Santana'},
#     {'gidp': '6',
#      'sac': '0',
#      'np': '1048',
#      'name_display_first_last': 'David Peralta',
#      'pos': 'LF',
#      'rank': '36',
#      'tb': '128',
#      'team_brief': 'D-backs',
#      'sport_id': '1',
#      'name_display_last_init': 'Peralta, D',
#      'bb': '24',
#      'avg': '.290',
#      'slg': '.489',
#      'ops': '.844',
#      'hbp': '3',
#      'team_abbrev': 'ARI',
#      'so': '65',
#      'league_id': '104',
#      'sf': '1',
#      'team': 'ari',
#      'league': 'NL',
#      'cs': '0',
#      'sb': '0',
#      'go_ao': '1.35',
#      'last_name': 'Peralta',
#      'player_id': '444482',
#      'ibb': '3',
#      'player_qualifier': '290',
#      'team_id': '109',
#      'go': '70',
#      'hr': '9',
#      'minimum_qualifier': '245',
#      'gdp': '6',
#      'name_display_roster': 'Peralta, David',
#      'qualifies': 'Y',
#      'rbi': '40',
#      'name_first': 'David',
#      'bats': 'L',
#      'xbh': '32',
#      'g': '64',
#      'd': '21',
#      'team_name': 'Arizona Diamondbacks',
#      'sport': 'MLB',
#      'tpa': '290',
#      'name_display_last_first': 'Peralta, David',
#      'h': '76',
#      'obp': '.355',
#      't': '2',
#      'ao': '52',
#      'r': '35',
#      'ab': '262',
#      'name_last': 'Peralta'},
#     {'gidp': '4',
#      'sac': '0',
#      'np': '1553',
#      'name_display_first_last': 'Ronald Acuna Jr.',
#      'pos': 'LF',
#      'rank': '37',
#      'tb': '157',
#      'team_brief': 'Braves',
#      'sport_id': '1',
#      'name_display_last_init': 'Acuna Jr., R',
#      'bb': '34',
#      'avg': '.289',
#      'slg': '.498',
#      'ops': '.867',
#      'hbp': '6',
#      'team_abbrev': 'ATL',
#      'so': '83',
#      'league_id': '104',
#      'sf': '0',
#      'team': 'atl',
#      'league': 'NL',
#      'cs': '3',
#      'sb': '10',
#      'go_ao': '0.78',
#      'last_name': 'Acuna',
#      'player_id': '660670',
#      'ibb': '2',
#      'player_qualifier': '358',
#      'team_id': '144',
#      'go': '62',
#      'hr': '18',
#      'minimum_qualifier': '245',
#      'gdp': '4',
#      'name_display_roster': 'Acuna Jr., Ronald',
#      'qualifies': 'Y',
#      'rbi': '50',
#      'name_first': 'Ronald',
#      'bats': 'R',
#      'xbh': '29',
#      'g': '78',
#      'd': '10',
#      'team_name': 'Atlanta Braves',
#      'sport': 'MLB',
#      'tpa': '358',
#      'name_display_last_first': 'Acuna Jr., Ronald',
#      'h': '91',
#      'obp': '.369',
#      't': '1',
#      'ao': '79',
#      'r': '54',
#      'ab': '315',
#      'name_last': 'Acuna'},
#     {'gidp': '1',
#      'sac': '0',
#      'np': '1337',
#      'name_display_first_last': 'Shin-Soo Choo',
#      'pos': 'LF',
#      'rank': '38',
#      'tb': '140',
#      'team_brief': 'Rangers',
#      'sport_id': '1',
#      'name_display_last_init': 'Choo, S',
#      'bb': '35',
#      'avg': '.289',
#      'slg': '.505',
#      'ops': '.894',
#      'hbp': '10',
#      'team_abbrev': 'TEX',
#      'so': '78',
#      'league_id': '103',
#      'sf': '0',
#      'team': 'tex',
#      'league': 'AL',
#      'cs': '1',
#      'sb': '6',
#      'go_ao': '1.05',
#      'last_name': 'Choo',
#      'player_id': '425783',
#      'ibb': '2',
#      'player_qualifier': '322',
#      'team_id': '140',
#      'go': '61',
#      'hr': '12',
#      'minimum_qualifier': '242',
#      'gdp': '1',
#      'name_display_roster': 'Choo, Shin-Soo',
#      'qualifies': 'Y',
#      'rbi': '32',
#      'name_first': 'Shin-Soo',
#      'bats': 'L',
#      'xbh': '34',
#      'g': '73',
#      'd': '20',
#      'team_name': 'Texas Rangers',
#      'sport': 'MLB',
#      'tpa': '322',
#      'name_display_last_first': 'Choo, Shin-Soo',
#      'h': '80',
#      'obp': '.388',
#      't': '2',
#      'ao': '58',
#      'r': '52',
#      'ab': '277',
#      'name_last': 'Choo'},
#     {'gidp': '2',
#      'sac': '0',
#      'np': '1001',
#      'name_display_first_last': 'Francisco Lindor',
#      'pos': 'SS',
#      'rank': '39',
#      'tb': '119',
#      'team_brief': 'Indians',
#      'sport_id': '1',
#      'name_display_last_init': 'Lindor, F',
#      'bb': '23',
#      'avg': '.289',
#      'slg': '.498',
#      'ops': '.850',
#      'hbp': '2',
#      'team_abbrev': 'CLE',
#      'so': '43',
#      'league_id': '103',
#      'sf': '3',
#      'team': 'cle',
#      'league': 'AL',
#      'cs': '1',
#      'sb': '11',
#      'go_ao': '1.06',
#      'last_name': 'Lindor',
#      'player_id': '596019',
#      'ibb': '5',
#      'player_qualifier': '267',
#      'team_id': '114',
#      'go': '67',
#      'hr': '12',
#      'minimum_qualifier': '242',
#      'gdp': '2',
#      'name_display_roster': 'Lindor, Francisco',
#      'qualifies': 'Y',
#      'rbi': '27',
#      'name_first': 'Francisco',
#      'bats': 'S',
#      'xbh': '25',
#      'g': '59',
#      'd': '12',
#      'team_name': 'Cleveland Indians',
#      'sport': 'MLB',
#      'tpa': '267',
#      'name_display_last_first': 'Lindor, Francisco',
#      'h': '69',
#      'obp': '.352',
#      't': '1',
#      'ao': '63',
#      'r': '38',
#      'ab': '239',
#      'name_last': 'Lindor'},
#     {'gidp': '9',
#      'sac': '0',
#      'np': '1190',
#      'name_display_first_last': 'Javier Baez',
#      'pos': 'SS',
#      'rank': '40',
#      'tb': '170',
#      'team_brief': 'Cubs',
#      'sport_id': '1',
#      'name_display_last_init': 'Baez, J',
#      'bb': '18',
#      'avg': '.287',
#      'slg': '.554',
#      'ops': '.879',
#      'hbp': '0',
#      'team_abbrev': 'CHC',
#      'so': '96',
#      'league_id': '104',
#      'sf': '1',
#      'team': 'chn',
#      'league': 'NL',
#      'cs': '4',
#      'sb': '5',
#      'go_ao': '1.53',
#      'last_name': 'Baez',
#      'player_id': '595879',
#      'ibb': '2',
#      'player_qualifier': '326',
#      'team_id': '112',
#      'go': '75',
#      'hr': '19',
#      'minimum_qualifier': '242',
#      'gdp': '9',
#      'name_display_roster': 'Baez, Javier',
#      'qualifies': 'Y',
#      'rbi': '52',
#      'name_first': 'Javier',
#      'bats': 'R',
#      'xbh': '41',
#      'g': '76',
#      'd': '19',
#      'team_name': 'Chicago Cubs',
#      'sport': 'MLB',
#      'tpa': '326',
#      'name_display_last_first': 'Baez, Javier',
#      'h': '88',
#      'obp': '.325',
#      't': '3',
#      'ao': '49',
#      'r': '51',
#      'ab': '307',
#      'name_last': 'Baez'},
#     {'gidp': '8',
#      'sac': '0',
#      'np': '961',
#      'name_display_first_last': 'Yandy Diaz',
#      'pos': '3B',
#      'rank': '41',
#      'tb': '109',
#      'team_brief': 'Rays',
#      'sport_id': '1',
#      'name_display_last_init': 'Diaz, Y',
#      'bb': '27',
#      'avg': '.286',
# ...
#      'team_id': '141',
#      'go': '47',
#      'hr': '12',
#      'minimum_qualifier': '245',
#      'gdp': '4',
#      'name_display_roster': 'Smoak, Justin',
#      'qualifies': 'Y',
#      'rbi': '34',
#      'name_first': 'Justin',
#      'bats': 'S',
#      'xbh': '18',
#      'g': '62',
#      'd': '6',
#      'team_name': 'Toronto Blue Jays',
#      'sport': 'MLB',
#      'tpa': '261',
#      'name_display_last_first': 'Smoak, Justin',
#      'h': '48',
#      'obp': '.364',
#      't': '0',
#      'ao': '72',
#      'r': '29',
#      'ab': '213',
#      'name_last': 'Smoak'},
#     {'gidp': '2',
#      'sac': '0',
#      'np': '1131',
#      'name_display_first_last': 'Jake Bauers',
#      'pos': 'LF',
#      'rank': '149',
#      'tb': '94',
#      'team_brief': 'Indians',
#      'sport_id': '1',
#      'name_display_last_init': 'Bauers, J',
#      'bb': '26',
#      'avg': '.224',
#      'slg': '.384',
#      'ops': '.685',
#      'hbp': '2',
#      'team_abbrev': 'CLE',
#      'so': '72',
#      'league_id': '103',
#      'sf': '2',
#      'team': 'cle',
#      'league': 'AL',
#      'cs': '2',
#      'sb': '2',
#      'go_ao': '0.90',
#      'last_name': 'Bauers',
#      'player_id': '641343',
#      'ibb': '0',
#      'player_qualifier': '275',
#      'team_id': '114',
#      'go': '57',
#      'hr': '9',
#      'minimum_qualifier': '242',
#      'gdp': '2',
#      'name_display_roster': 'Bauers, Jake',
#      'qualifies': 'Y',
#      'rbi': '28',
#      'name_first': 'Jake',
#      'bats': 'L',
#      'xbh': '20',
#      'g': '73',
#      'd': '10',
#      'team_name': 'Cleveland Indians',
#      'sport': 'MLB',
#      'tpa': '275',
#      'name_display_last_first': 'Bauers, Jake',
#      'h': '55',
#      'obp': '.302',
#      't': '1',
#      'ao': '63',
#      'r': '31',
#      'ab': '245',
#      'name_last': 'Bauers'},
#     {'gidp': '3',
#      'sac': '0',
#      'np': '1222',
#      'name_display_first_last': 'Mitch Haniger',
#      'pos': 'RF',
#      'rank': '150',
#      'tb': '114',
#      'team_brief': 'Mariners',
#      'sport_id': '1',
#      'name_display_last_init': 'Haniger, M',
#      'bb': '30',
#      'avg': '.220',
#      'slg': '.463',
#      'ops': '.778',
#      'hbp': '5',
#      'team_abbrev': 'SEA',
#      'so': '81',
#      'league_id': '103',
#      'sf': '2',
#      'team': 'sea',
#      'league': 'AL',
#      'cs': '0',
#      'sb': '4',
#      'go_ao': '0.77',
#      'last_name': 'Haniger',
#      'player_id': '571745',
#      'ibb': '1',
#      'player_qualifier': '283',
#      'team_id': '136',
#      'go': '49',
#      'hr': '15',
#      'minimum_qualifier': '254',
#      'gdp': '3',
#      'name_display_roster': 'Haniger, Mitch',
#      'qualifies': 'Y',
#      'rbi': '32',
#      'name_first': 'Mitch',
#      'bats': 'R',
#      'xbh': '29',
#      'g': '63',
#      'd': '13',
#      'team_name': 'Seattle Mariners',
#      'sport': 'MLB',
#      'tpa': '283',
#      'name_display_last_first': 'Haniger, Mitch',
#      'h': '54',
#      'obp': '.314',
#      't': '1',
#      'ao': '64',
#      'r': '46',
#      'ab': '246',
#      'name_last': 'Haniger'},
#     {'gidp': '8',
#      'sac': '1',
#      'np': '1145',
#      'name_display_first_last': 'Wil Myers',
#      'pos': 'LF',
#      'rank': '151',
#      'tb': '95',
#      'team_brief': 'Padres',
#      'sport_id': '1',
#      'name_display_last_init': 'Myers, W',
#      'bb': '31',
#      'avg': '.219',
#      'slg': '.401',
#      'ops': '.716',
#      'hbp': '2',
#      'team_abbrev': 'SD',
#      'so': '97',
#      'league_id': '104',
#      'sf': '0',
#      'team': 'sdn',
#      'league': 'NL',
#      'cs': '3',
#      'sb': '9',
#      'go_ao': '1.07',
#      'last_name': 'Myers',
#      'player_id': '571976',
#      'ibb': '0',
#      'player_qualifier': '271',
#      'team_id': '135',
#      'go': '46',
#      'hr': '11',
#      'minimum_qualifier': '242',
#      'gdp': '8',
#      'name_display_roster': 'Myers, Wil',
#      'qualifies': 'Y',
#      'rbi': '24',
#      'name_first': 'Wil',
#      'bats': 'R',
#      'xbh': '21',
#      'g': '76',
#      'd': '10',
#      'team_name': 'San Diego Padres',
#      'sport': 'MLB',
#      'tpa': '271',
#      'name_display_last_first': 'Myers, Wil',
#      'h': '52',
#      'obp': '.315',
#      't': '0',
#      'ao': '43',
#      'r': '39',
#      'ab': '237',
#      'name_last': 'Myers'},
#     {'gidp': '6',
#      'sac': '0',
#      'np': '1131',
#      'name_display_first_last': 'Jurickson Profar',
#      'pos': '2B',
#      'rank': '152',
#      'tb': '103',
#      'team_brief': 'Athletics',
#      'sport_id': '1',
#      'name_display_last_init': 'Profar, J',
#      'bb': '19',
#      'avg': '.219',
#      'slg': '.383',
#      'ops': '.663',
#      'hbp': '4',
#      'team_abbrev': 'OAK',
#      'so': '44',
#      'league_id': '103',
#      'sf': '1',
#      'team': 'oak',
#      'league': 'AL',
#      'cs': '0',
#      'sb': '6',
#      'go_ao': '0.90',
#      'last_name': 'Profar',
#      'player_id': '595777',
#      'ibb': '2',
#      'player_qualifier': '293',
#      'team_id': '133',
#      'go': '79',
#      'hr': '10',
#      'minimum_qualifier': '248',
#      'gdp': '6',
#      'name_display_roster': 'Profar, Jurickson',
#      'qualifies': 'Y',
#      'rbi': '40',
#      'name_first': 'Jurickson',
#      'bats': 'S',
#      'xbh': '23',
#      'g': '72',
#      'd': '12',
#      'team_name': 'Oakland Athletics',
#      'sport': 'MLB',
#      'tpa': '293',
#      'name_display_last_first': 'Profar, Jurickson',
#      'h': '59',
#      'obp': '.280',
#      't': '1',
#      'ao': '88',
#      'r': '31',
#      'ab': '269',
#      'name_last': 'Profar'},
#     {'gidp': '5',
#      'sac': '3',
#      'np': '1077',
#      'name_display_first_last': 'Jackie Bradley Jr.',
#      'pos': 'CF',
#      'rank': '153',
#      'tb': '93',
#      'team_brief': 'Red Sox',
#      'sport_id': '1',
#      'name_display_last_init': 'Bradley Jr., J',
#      'bb': '30',
#      'avg': '.218',
#      'slg': '.391',
#      'ops': '.713',
#      'hbp': '7',
#      'team_abbrev': 'BOS',
#      'so': '73',
#      'league_id': '103',
#      'sf': '1',
#      'team': 'bos',
#      'league': 'AL',
#      'cs': '2',
#      'sb': '6',
#      'go_ao': '1.49',
#      'last_name': 'Bradley Jr.',
#      'player_id': '598265',
#      'ibb': '3',
#      'player_qualifier': '279',
#      'team_id': '111',
#      'go': '70',
#      'hr': '8',
#      'minimum_qualifier': '248',
#      'gdp': '5',
#      'name_display_roster': 'Bradley Jr., Jackie',
#      'qualifies': 'Y',
#      'rbi': '27',
#      'name_first': 'Jackie',
#      'bats': 'L',
#      'xbh': '24',
#      'g': '71',
#      'd': '15',
#      'team_name': 'Boston Red Sox',
#      'sport': 'MLB',
#      'tpa': '279',
#      'name_display_last_first': 'Bradley Jr., Jackie',
#      'h': '52',
#      'obp': '.322',
#      't': '1',
#      'ao': '47',
#      'r': '30',
#      'ab': '238',
#      'name_last': 'Bradley Jr.'},
#     {'gidp': '3',
#      'sac': '0',
#      'np': '1427',
#      'name_display_first_last': 'Matt Carpenter',
#      'pos': '3B',
#      'rank': '154',
#      'tb': '103',
#      'team_brief': 'Cardinals',
#      'sport_id': '1',
#      'name_display_last_init': 'Carpenter, M',
#      'bb': '44',
#      'avg': '.218',
#      'slg': '.380',
#      'ops': '.709',
#      'hbp': '2',
#      'team_abbrev': 'STL',
#      'so': '78',
#      'league_id': '104',
#      'sf': '2',
#      'team': 'sln',
#      'league': 'NL',
#      'cs': '1',
#      'sb': '6',
#      'go_ao': '0.53',
#      'last_name': 'Carpenter',
#      'player_id': '572761',
#      'ibb': '0',
#      'player_qualifier': '319',
#      'team_id': '138',
#      'go': '47',
#      'hr': '10',
#      'minimum_qualifier': '239',
#      'gdp': '3',
#      'name_display_roster': 'Carpenter, Matt',
#      'qualifies': 'Y',
#      'rbi': '26',
#      'name_first': 'Matt',
#      'bats': 'L',
#      'xbh': '23',
#      'g': '74',
#      'd': '12',
#      'team_name': 'St. Louis Cardinals',
#      'sport': 'MLB',
#      'tpa': '319',
#      'name_display_last_first': 'Carpenter, Matt',
#      'h': '59',
#      'obp': '.329',
#      't': '1',
#      'ao': '89',
#      'r': '41',
#      'ab': '271',
#      'name_last': 'Carpenter'},
#     {'gidp': '6',
#      'sac': '0',
#      'np': '1304',
#      'name_display_first_last': 'Jose Ramirez',
#      'pos': '3B',
#      'rank': '155',
#      'tb': '95',
#      'team_brief': 'Indians',
#      'sport_id': '1',
#      'name_display_last_init': 'Ramirez, J',
#      'bb': '37',
#      'avg': '.217',
#      'slg': '.332',
#      'ops': '.640',
#      'hbp': '2',
#      'team_abbrev': 'CLE',
#      'so': '43',
#      'league_id': '103',
#      'sf': '3',
#      'team': 'cle',
#      'league': 'AL',
#      'cs': '2',
#      'sb': '18',
#      'go_ao': '0.48',
#      'last_name': 'Ramirez',
#      'player_id': '608070',
#      'ibb': '3',
#      'player_qualifier': '328',
#      'team_id': '114',
#      'go': '60',
#      'hr': '5',
#      'minimum_qualifier': '242',
#      'gdp': '6',
#      'name_display_roster': 'Ramirez, Jose',
#      'qualifies': 'Y',
#      'rbi': '30',
#      'name_first': 'Jose',
#      'bats': 'S',
#      'xbh': '21',
#      'g': '77',
#      'd': '14',
#      'team_name': 'Cleveland Indians',
#      'sport': 'MLB',
#      'tpa': '328',
#      'name_display_last_first': 'Ramirez, Jose',
#      'h': '62',
#      'obp': '.308',
#      't': '2',
#      'ao': '124',
#      'r': '32',
#      'ab': '286',
#      'name_last': 'Ramirez'},
#     {'gidp': '9',
#      'sac': '0',
#      'np': '876',
#      'name_display_first_last': 'Maikel Franco',
#      'pos': '3B',
#      'rank': '156',
#      'tb': '89',
#      'team_brief': 'Phillies',
#      'sport_id': '1',
#      'name_display_last_init': 'Franco, M',
#      'bb': '23',
#      'avg': '.214',
#      'slg': '.389',
#      'ops': '.673',
#      'hbp': '0',
#      'team_abbrev': 'PHI',
#      'so': '30',
#      'league_id': '104',
#      'sf': '1',
#      'team': 'phi',
#      'league': 'NL',
#      'cs': '0',
#      'sb': '0',
#      'go_ao': '0.96',
#      'last_name': 'Franco',
#      'player_id': '596748',
#      'ibb': '14',
#      'player_qualifier': '253',
#      'team_id': '143',
#      'go': '74',
#      'hr': '10',
#      'minimum_qualifier': '242',
#      'gdp': '9',
#      'name_display_roster': 'Franco, Maikel',
#      'qualifies': 'Y',
#      'rbi': '35',
#      'name_first': 'Maikel',
#      'bats': 'R',
#      'xbh': '20',
#      'g': '70',
#      'd': '10',
#      'team_name': 'Philadelphia Phillies',
#      'sport': 'MLB',
#      'tpa': '253',
#      'name_display_last_first': 'Franco, Maikel',
#      'h': '49',
#      'obp': '.285',
#      't': '0',
#      'ao': '77',
#      'r': '29',
#      'ab': '229',
#      'name_last': 'Franco'},
#     {'gidp': '5',
#      'sac': '0',
#      'np': '1065',
#      'name_display_first_last': 'Brandon Crawford',
#      'pos': 'SS',
#      'rank': '157',
#      'tb': '82',
#      'team_brief': 'Giants',
#      'sport_id': '1',
#      'name_display_last_init': 'Crawford, B',
#      'bb': '23',
#      'avg': '.214',
#      'slg': '.331',
#      'ops': '.611',
#      'hbp': '1',
#      'team_abbrev': 'SF',
#      'so': '65',
#      'league_id': '104',
#      'sf': '3',
#      'team': 'sfn',
#      'league': 'NL',
#      'cs': '1',
#      'sb': '2',
#      'go_ao': '1.25',
#      'last_name': 'Crawford',
#      'player_id': '543063',
#      'ibb': '2',
#      'player_qualifier': '275',
#      'team_id': '137',
#      'go': '74',
#      'hr': '5',
#      'minimum_qualifier': '236',
#      'gdp': '5',
#      'name_display_roster': 'Crawford, Brandon',
#      'qualifies': 'Y',
#      'rbi': '27',
#      'name_first': 'Brandon',
#      'bats': 'L',
#      'xbh': '18',
#      'g': '72',
#      'd': '12',
#      'team_name': 'San Francisco Giants',
#      'sport': 'MLB',
#      'tpa': '275',
#      'name_display_last_first': 'Crawford, Brandon',
#      'h': '53',
#      'obp': '.280',
#      't': '1',
#      'ao': '59',
#      'r': '24',
#      'ab': '248',
#      'name_last': 'Crawford'},
#     {'gidp': '1',
#      'sac': '0',
#      'np': '1094',
#      'name_display_first_last': 'Enrique Hernandez',
#      'pos': '2B',
#      'rank': '158',
#      'tb': '95',
#      'team_brief': 'Dodgers',
#      'sport_id': '1',
#      'name_display_last_init': 'Hernandez, K',
#      'bb': '21',
#      'avg': '.212',
#      'slg': '.388',
#      'ops': '.670',
#      'hbp': '4',
#      'team_abbrev': 'LAD',
#      'so': '63',
#      'league_id': '104',
#      'sf': '3',
#      'team': 'lan',
#      'league': 'NL',
#      'cs': '0',
#      'sb': '2',
#      'go_ao': '0.68',
#      'last_name': 'Hernandez',
#      'player_id': '571771',
#      'ibb': '2',
#      'player_qualifier': '273',
#      'team_id': '119',
#      'go': '54',
#      'hr': '11',
#      'minimum_qualifier': '245',
#      'gdp': '1',
#      'name_display_roster': 'Hernandez, Enrique',
#      'qualifies': 'Y',
#      'rbi': '37',
#      'name_first': 'Enrique',
#      'bats': 'R',
#      'xbh': '20',
#      'g': '73',
#      'd': '8',
#      'team_name': 'Los Angeles Dodgers',
#      'sport': 'MLB',
#      'tpa': '273',
#      'name_display_last_first': 'Hernandez, Enrique',
#      'h': '52',
#      'obp': '.282',
#      't': '1',
#      'ao': '79',
#      'r': '30',
#      'ab': '245',
#      'name_last': 'Hernandez'},
#     {'gidp': '1',
#      'sac': '3',
#      'np': '1023',
#      'name_display_first_last': 'Leonys Martin',
#      'pos': 'CF',
#      'rank': '159',
#      'tb': '81',
#      'team_brief': 'Indians',
#      'sport_id': '1',
#      'name_display_last_init': 'Martin, L',
#      'bb': '21',
#      'avg': '.199',
#      'slg': '.343',
#      'ops': '.619',
#      'hbp': '4',
#      'team_abbrev': 'CLE',
#      'so': '78',
#      'league_id': '103',
#      'sf': '0',
#      'team': 'cle',
#      'league': 'AL',
#      'cs': '5',
#      'sb': '4',
#      'go_ao': '0.84',
#      'last_name': 'Martin',
#      'player_id': '547982',
#      'ibb': '0',
#      'player_qualifier': '264',
#      'team_id': '114',
#      'go': '52',
#      'hr': '9',
#      'minimum_qualifier': '242',
#      'gdp': '1',
#      'name_display_roster': 'Martin, Leonys',
#      'qualifies': 'Y',
#      'rbi': '19',
#      'name_first': 'Leonys',
#      'bats': 'L',
#      'xbh': '16',
#      'g': '65',
#      'd': '7',
#      'team_name': 'Cleveland Indians',
#      'sport': 'MLB',
#      'tpa': '264',
#      'name_display_last_first': 'Martin, Leonys',
#      'h': '47',
#      'obp': '.276',
#      't': '0',
#      'ao': '62',
#      'r': '32',
#      'ab': '236',
#      'name_last': 'Martin'},
#     {'gidp': '7',
#      'sac': '0',
#      'np': '1023',
#      'name_display_first_last': 'Yonder Alonso',
#      'pos': '1B',
#      'rank': '160',
#      'tb': '66',
#      'team_brief': 'White Sox',
#      'sport_id': '1',
#      'name_display_last_init': 'Alonso, Y',
#      'bb': '29',
#      'avg': '.179',
#      'slg': '.303',
#      'ops': '.579',
#      'hbp': '1',
#      'team_abbrev': 'CWS',
#      'so': '53',
#      'league_id': '103',
#      'sf': '2',
#      'team': 'cha',
#      'league': 'AL',
#      'cs': '1',
#      'sb': '0',
#      'go_ao': '0.91',
#      'last_name': 'Alonso',
#      'player_id': '475174',
#      'ibb': '2',
#      'player_qualifier': '250',
#      'team_id': '145',
#      'go': '61',
#      'hr': '7',
#      'minimum_qualifier': '236',
#      'gdp': '7',
#      'name_display_roster': 'Alonso, Yonder',
#      'qualifies': 'Y',
#      'rbi': '27',
#      'name_first': 'Yonder',
#      'bats': 'L',
#      'xbh': '13',
#      'g': '66',
#      'd': '6',
#      'team_name': 'Chicago White Sox',
#      'sport': 'MLB',
#      'tpa': '250',
#      'name_display_last_first': 'Alonso, Yonder',
#      'h': '39',
#      'obp': '.276',
#      't': '0',
#      'ao': '67',
#      'r': '23',
#      'ab': '218',
#      'name_last': 'Alonso'},
#     {'gidp': '3',
#      'sac': '1',
#      'np': '1077',
#      'name_display_first_last': 'Rougned Odor',
#      'pos': '2B',
#      'rank': '161',
#      'tb': '82',
#      'team_brief': 'Rangers',
#      'sport_id': '1',
#      'name_display_last_init': 'Odor, R',
#      'bb': '22',
#      'avg': '.175',
#      'slg': '.350',
#      'ops': '.599',
#      'hbp': '1',
#      'team_abbrev': 'TEX',
#      'so': '82',
#      'league_id': '103',
#      'sf': '0',
#      'team': 'tex',
#      'league': 'AL',
#      'cs': '5',
#      'sb': '7',
#      'go_ao': '0.87',
#      'last_name': 'Odor',
#      'player_id': '596059',
#      'ibb': '0',
#      'player_qualifier': '258',
#      'team_id': '140',
#      'go': '52',
#      'hr': '10',
#      'minimum_qualifier': '242',
#      'gdp': '3',
#      'name_display_roster': 'Odor, Rougned',
#      'qualifies': 'Y',
#      'rbi': '36',
#      'name_first': 'Rougned',
#      'bats': 'L',
#      'xbh': '21',
#      'g': '64',
#      'd': '11',
#      'team_name': 'Texas Rangers',
#      'sport': 'MLB',
#      'tpa': '258',
#      'name_display_last_first': 'Odor, Rougned',
#      'h': '41',
#      'obp': '.249',
#      't': '0',
#      'ao': '60',
#      'r': '34',
#      'ab': '234',
#      'name_last': 'Odor'}]}}}

# %%
# checkpoint
# 透過一層一層解析到達球員數據層
# 並查看第一位球員數據
doc_json['stats_sortable_player']['queryResults']['row'][0]
# Out:
# {'gidp': '3',
#  'sac': '0',
#  'np': '1334',
#  'name_display_first_last': 'Cody Bellinger',
#  'pos': 'RF',
#  'rank': '1',
#  'tb': '190',
#  'team_brief': 'Dodgers',
#  'sport_id': '1',
#  'name_display_last_init': 'Bellinger, C',
#  'bb': '48',
#  'avg': '.349',
#  'slg': '.699',
#  'ops': '1.143',
#  'hbp': '1',
#  'team_abbrev': 'LAD',
#  'so': '49',
#  'league_id': '104',
#  'sf': '3',
#  'team': 'lan',
#  'league': 'NL',
#  'cs': '5',
#  'sb': '8',
#  'go_ao': '0.52',
#  'last_name': 'Bellinger',
#  'player_id': '641355',
#  'ibb': '10',
#  'player_qualifier': '324',
#  'team_id': '119',
#  'go': '45',
#  'hr': '25',
#  'minimum_qualifier': '245',
#  'gdp': '3',
#  'name_display_roster': 'Bellinger, Cody',
#  'qualifies': 'Y',
#  'rbi': '61',
#  'name_first': 'Cody',
#  'bats': 'L',
#  'xbh': '43',
#  'g': '76',
#  'd': '16',
#  'team_name': 'Los Angeles Dodgers',
#  'sport': 'MLB',
#  'tpa': '324',
#  'name_display_last_first': 'Bellinger, Cody',
#  'h': '95',
#  'obp': '.444',
#  't': '2',
#  'ao': '86',
#  'r': '61',
#  'ab': '272',
#  'name_last': 'Bellinger'}

# %% [markdown]
# ### 各數據對應key
#
# 球員數據層
# `doc_json['stats_sortable_player']['queryResults']['row']`
#
# * 打者數據：
#     * 打數
#         * `'ab'`
#     * 上壘率
#         * `'obp'`
#     * 聯盟平均上壘率
#         * ??
#     * 長打率
#         * `'slg'`
#     * 聯盟平均長打率
#         * ??
#     * 整體攻擊指數
#         * `'ops'`
# ---
# * 註：`聯盟平均上壘率和聯盟平均長打率因為不屬於選手數據所以不再所得的Data內，可能要看是要直接在網站上找資料或是拿所有選手的數據加總來計算`

# %%
# 透過一層一層解析到達球員數據層
# 並將其儲存為一變數方便重複使用
player_stats_json = doc_json['stats_sortable_player']['queryResults']['row']

# %%
# 建立各list儲存各資料
# 準備放入DataFrame中
player_list = []
ab_list = []
obp_list = []
slg_list = []
ops_list = []

# %%
# 展示特定球員我們所需要的資料
def show_player_stats(index):
    print('Player: ',player_stats_json[index]['name_display_last_init'])
    print('AB    : ',player_stats_json[index]['ab'])
    print('OBP   : ',player_stats_json[index]['obp'])
    print('SLG   : ',player_stats_json[index]['slg'])
    print('OPS   : ',player_stats_json[index]['ops'])
    
# 將各球員資料儲存到list中
def store_player_stats(index):
    player_list.append(player_stats_json[index]['name_display_last_init'])
    ab_list.append(player_stats_json[index]['ab'])
    obp_list.append(player_stats_json[index]['obp'])
    slg_list.append(player_stats_json[index]['slg'])
    ops_list.append(player_stats_json[index]['ops'])

# %%
# checkpoint
# 試查看第一位球員
show_player_stats(0)
# Out:
# Player:  Bellinger, C
# AB    :  272
# OBP   :  .444
# SLG   :  .699
# OPS   :  1.143

# %%
# 透過迴圈展示所有球員
# 並將球員資料儲存到list中
for i in range(len(player_stats_json)):
    show_player_stats(i)
    store_player_stats(i)
    print('------------------------')
# Out:
# Player:  Bellinger, C
# AB    :  272
# OBP   :  .444
# SLG   :  .699
# OPS   :  1.143
# ------------------------
# Player:  Yelich, C
# AB    :  266
# OBP   :  .435
# SLG   :  .744
# OPS   :  1.179
# ------------------------
# Player:  McNeil, J
# AB    :  242
# OBP   :  .403
# SLG   :  .488
# OPS   :  .891
# ------------------------
# Player:  LeMahieu, D
# AB    :  293
# OBP   :  .380
# SLG   :  .495
# OPS   :  .875
# ------------------------
# Player:  Blackmon, C
# AB    :  269
# OBP   :  .376
# SLG   :  .643
# OPS   :  1.019
# ------------------------
# Player:  Polanco, J
# AB    :  301
# OBP   :  .383
# SLG   :  .542
# OPS   :  .925
# ------------------------
# Player:  Arenado, N
# AB    :  296
# OBP   :  .386
# SLG   :  .588
# OPS   :  .973
# ------------------------
# Player:  Brantley, M
# AB    :  295
# OBP   :  .382
# SLG   :  .512
# OPS   :  .893
# ------------------------
# Player:  Dahl, D
# AB    :  254
# OBP   :  .370
# SLG   :  .524
# OPS   :  .894
# ------------------------
# Player:  Freeman, F
# AB    :  308
# OBP   :  .402
# SLG   :  .601
# OPS   :  1.003
# ------------------------
# Player:  Bell, J
# AB    :  289
# OBP   :  .386
# SLG   :  .640
# OPS   :  1.026
# ------------------------
# Player:  Anderson, T
# AB    :  268
# OBP   :  .338
# SLG   :  .485
# OPS   :  .823
# ------------------------
# Player:  Rendon, A
# AB    :  232
# OBP   :  .404
# SLG   :  .634
# OPS   :  1.038
# ------------------------
# Player:  Marte, K
# AB    :  307
# OBP   :  .359
# SLG   :  .586
# OPS   :  .946
# ------------------------
# Player:  Devers, R
# AB    :  302
# OBP   :  .362
# SLG   :  .503
# OPS   :  .865
# ------------------------
# Player:  Trout, M
# AB    :  257
# OBP   :  .466
# SLG   :  .642
# OPS   :  1.108
# ------------------------
# Player:  Soto, J
# AB    :  249
# OBP   :  .399
# SLG   :  .534
# OPS   :  .933
# ------------------------
# Player:  Mancini, T
# AB    :  282
# OBP   :  .364
# SLG   :  .564
# OPS   :  .928
# ------------------------
# Player:  Meadows, A
# AB    :  230
# OBP   :  .377
# SLG   :  .552
# OPS   :  .930
# ------------------------
# Player:  Andrus, E
# AB    :  280
# OBP   :  .340
# SLG   :  .464
# OPS   :  .804
# ------------------------
# Player:  Merrifield, W
# AB    :  330
# OBP   :  .350
# SLG   :  .506
# OPS   :  .856
# ------------------------
# Player:  Verdugo, A
# AB    :  225
# OBP   :  .352
# SLG   :  .489
# OPS   :  .841
# ------------------------
# Player:  Turner, J
# AB    :  253
# OBP   :  .380
# SLG   :  .435
# OPS   :  .815
# ------------------------
# Player:  Moncada, Y
# AB    :  274
# OBP   :  .352
# SLG   :  .522
# OPS   :  .874
# ------------------------
# Player:  La Stella, T
# AB    :  259
# OBP   :  .350
# SLG   :  .498
# OPS   :  .848
# ------------------------
# Player:  Reddick, J
# AB    :  263
# OBP   :  .337
# SLG   :  .441
# OPS   :  .778
# ------------------------
# Player:  Bogaerts, X
# AB    :  297
# OBP   :  .388
# SLG   :  .529
# OPS   :  .917
# ------------------------
# Player:  Cabrera, M
# AB    :  247
# OBP   :  .359
# SLG   :  .389
# OPS   :  .747
# ------------------------
# Player:  Contreras, W
# AB    :  221
# OBP   :  .388
# SLG   :  .561
# OPS   :  .949
# ------------------------
# Player:  Iglesias, J
# AB    :  238
# OBP   :  .333
# SLG   :  .420
# OPS   :  .754
# ------------------------
# Player:  Pham, T
# AB    :  272
# OBP   :  .401
# SLG   :  .474
# OPS   :  .875
# ------------------------
# Player:  Story, T
# AB    :  296
# OBP   :  .360
# SLG   :  .547
# OPS   :  .907
# ------------------------
# Player:  Garcia, A
# AB    :  262
# OBP   :  .352
# SLG   :  .477
# OPS   :  .829
# ------------------------
# Player:  Fletcher, D
# AB    :  263
# OBP   :  .346
# SLG   :  .411
# OPS   :  .757
# ------------------------
# Player:  Santana, C
# AB    :  275
# OBP   :  .413
# SLG   :  .538
# OPS   :  .951
# ------------------------
# Player:  Peralta, D
# AB    :  262
# OBP   :  .355
# SLG   :  .489
# OPS   :  .844
# ------------------------
# Player:  Acuna Jr., R
# AB    :  315
# OBP   :  .369
# SLG   :  .498
# OPS   :  .867
# ------------------------
# Player:  Choo, S
# AB    :  277
# OBP   :  .388
# SLG   :  .505
# OPS   :  .894
# ------------------------
# Player:  Lindor, F
# AB    :  239
# OBP   :  .352
# SLG   :  .498
# OPS   :  .850
# ------------------------
# Player:  Baez, J
# AB    :  307
# OBP   :  .325
# SLG   :  .554
# OPS   :  .879
# ------------------------
# Player:  Diaz, Y
# AB    :  217
# OBP   :  .363
# SLG   :  .502
# OPS   :  .865
# ------------------------
# Player:  Bryant, K
# AB    :  274
# OBP   :  .394
# SLG   :  .533
# OPS   :  .927
# ------------------------
# Player:  Torres, G
# AB    :  267
# OBP   :  .350
# SLG   :  .539
# OPS   :  .889
# ------------------------
# Player:  Albies, O
# AB    :  313
# OBP   :  .345
# SLG   :  .460
# OPS   :  .805
# ------------------------
# Player:  Martinez, J
# AB    :  278
# OBP   :  .362
# SLG   :  .518
# OPS   :  .880
# ------------------------
# Player:  Hosmer, E
# AB    :  297
# OBP   :  .340
# SLG   :  .441
# OPS   :  .782
# ------------------------
# Player:  Lowe, B
# AB    :  255
# OBP   :  .341
# SLG   :  .533
# OPS   :  .874
# ------------------------
# Player:  Santana, D
# AB    :  312
# OBP   :  .347
# SLG   :  .503
# OPS   :  .850
# ------------------------
# Player:  Escobar, E
# AB    :  305
# OBP   :  .341
# SLG   :  .538
# OPS   :  .879
# ------------------------
# Player:  Garcia, L
# AB    :  267
# OBP   :  .322
# SLG   :  .386
# OPS   :  .707
# ------------------------
# Player:  Cron, C
# AB    :  260
# OBP   :  .344
# SLG   :  .538
# OPS   :  .882
# ------------------------
# Player:  Desmond, I
# AB    :  228
# OBP   :  .341
# SLG   :  .518
# OPS   :  .859
# ------------------------
# Player:  Moustakas, M
# AB    :  271
# OBP   :  .359
# SLG   :  .583
# OPS   :  .942
# ------------------------
# Player:  Hernandez, C
# AB    :  289
# OBP   :  .334
# SLG   :  .433
# OPS   :  .767
# ------------------------
# Player:  Muncy, M
# AB    :  257
# OBP   :  .382
# SLG   :  .533
# OPS   :  .915
# ------------------------
# Player:  Alonso, P
# AB    :  282
# OBP   :  .373
# SLG   :  .642
# OPS   :  1.015
# ------------------------
# Player:  Ramos, W
# AB    :  222
# OBP   :  .356
# SLG   :  .432
# OPS   :  .788
# ------------------------
# Player:  Marte, S
# AB    :  276
# OBP   :  .321
# SLG   :  .475
# OPS   :  .796
# ------------------------
# Player:  Seager, C
# AB    :  237
# OBP   :  .359
# SLG   :  .468
# OPS   :  .828
# ------------------------
# Player:  Machado, M
# AB    :  288
# OBP   :  .354
# SLG   :  .493
# OPS   :  .847
# ------------------------
# Player:  Benintendi, A
# AB    :  292
# OBP   :  .359
# SLG   :  .438
# OPS   :  .798
# ------------------------
# Player:  Segura, J
# AB    :  278
# OBP   :  .324
# SLG   :  .450
# OPS   :  .774
# ------------------------
# Player:  Rizzo, A
# AB    :  271
# OBP   :  .388
# SLG   :  .539
# OPS   :  .927
# ------------------------
# Player:  Semien, M
# AB    :  322
# OBP   :  .359
# SLG   :  .438
# OPS   :  .797
# ------------------------
# Player:  Mazara, N
# AB    :  272
# OBP   :  .328
# SLG   :  .474
# OPS   :  .802
# ------------------------
# Player:  Markakis, N
# AB    :  276
# OBP   :  .359
# SLG   :  .413
# OPS   :  .772
# ------------------------
# Player:  Rojas, M
# AB    :  255
# OBP   :  .338
# SLG   :  .333
# OPS   :  .671
# ------------------------
# Player:  Eaton, A
# AB    :  281
# OBP   :  .360
# SLG   :  .388
# OPS   :  .748
# ------------------------
# Player:  Grandal, Y
# AB    :  241
# OBP   :  .384
# SLG   :  .544
# OPS   :  .927
# ------------------------
# Player:  Kepler, M
# AB    :  274
# OBP   :  .351
# SLG   :  .551
# OPS   :  .903
# ------------------------
# Player:  Jones, A
# AB    :  272
# OBP   :  .322
# SLG   :  .474
# OPS   :  .796
# ------------------------
# Player:  Choi, J
# AB    :  219
# OBP   :  .344
# SLG   :  .443
# OPS   :  .787
# ------------------------
# Player:  Rosario, E
# AB    :  301
# OBP   :  .300
# SLG   :  .518
# OPS   :  .818
# ------------------------
# Player:  Hoskins, R
# AB    :  275
# OBP   :  .398
# SLG   :  .527
# OPS   :  .925
# ------------------------
# Player:  Mondesi, A
# AB    :  290
# OBP   :  .302
# SLG   :  .441
# OPS   :  .744
# ------------------------
# Player:  Castellanos, N
# AB    :  283
# OBP   :  .328
# SLG   :  .452
# OPS   :  .780
# ------------------------
# Player:  Sanchez, G
# AB    :  220
# OBP   :  .336
# SLG   :  .623
# OPS   :  .959
# ------------------------
# Player:  Voit, L
# AB    :  280
# OBP   :  .387
# SLG   :  .493
# OPS   :  .880
# ------------------------
# Player:  Heyward, J
# AB    :  254
# OBP   :  .358
# SLG   :  .441
# OPS   :  .799
# ------------------------
# Player:  Chapman, M
# AB    :  297
# OBP   :  .353
# SLG   :  .529
# OPS   :  .882
# ------------------------
# Player:  Molina, Y
# AB    :  237
# OBP   :  .295
# SLG   :  .384
# OPS   :  .679
# ------------------------
# Player:  Laureano, R
# AB    :  286
# OBP   :  .311
# SLG   :  .448
# OPS   :  .758
# ------------------------
# Player:  Betts, M
# AB    :  305
# OBP   :  .386
# SLG   :  .469
# OPS   :  .855
# ------------------------
# Player:  Walker, C
# AB    :  268
# OBP   :  .337
# SLG   :  .489
# OPS   :  .826
# ------------------------
# Player:  Galvis, F
# AB    :  284
# OBP   :  .303
# SLG   :  .444
# OPS   :  .747
# ------------------------
# Player:  Braun, R
# AB    :  250
# OBP   :  .316
# SLG   :  .456
# OPS   :  .772
# ------------------------
# Player:  Conforto, M
# AB    :  250
# OBP   :  .381
# SLG   :  .516
# OPS   :  .897
# ------------------------
# Player:  DeJong, P
# AB    :  288
# OBP   :  .353
# SLG   :  .472
# OPS   :  .826
# ------------------------
# Player:  Frazier, A
# AB    :  262
# OBP   :  .325
# SLG   :  .378
# OPS   :  .703
# ------------------------
# Player:  Gurriel, Y
# AB    :  287
# OBP   :  .295
# SLG   :  .401
# OPS   :  .696
# ------------------------
# Player:  Gordon, A
# AB    :  276
# OBP   :  .342
# SLG   :  .449
# OPS   :  .791
# ------------------------
# Player:  Ahmed, N
# AB    :  273
# OBP   :  .310
# SLG   :  .414
# OPS   :  .724
# ------------------------
# Player:  Chavis, M
# AB    :  227
# OBP   :  .336
# SLG   :  .449
# OPS   :  .785
# ------------------------
# Player:  Votto, J
# AB    :  258
# OBP   :  .356
# SLG   :  .407
# OPS   :  .763
# ------------------------
# Player:  Realmuto, J
# AB    :  262
# OBP   :  .318
# SLG   :  .431
# OPS   :  .750
# ------------------------
# Player:  Donaldson, J
# AB    :  270
# OBP   :  .361
# SLG   :  .493
# OPS   :  .854
# ------------------------
# Player:  Schoop, J
# AB    :  243
# OBP   :  .308
# SLG   :  .469
# OPS   :  .777
# ------------------------
# Player:  Swanson, D
# AB    :  301
# OBP   :  .325
# SLG   :  .475
# OPS   :  .801
# ------------------------
# Player:  Bregman, A
# AB    :  278
# OBP   :  .388
# SLG   :  .522
# OPS   :  .910
# ------------------------
# Player:  Abreu, J
# AB    :  302
# OBP   :  .298
# SLG   :  .500
# OPS   :  .798
# ------------------------
# Player:  Rosario, A
# AB    :  291
# OBP   :  .297
# SLG   :  .416
# OPS   :  .713
# ------------------------
# Player:  Smith Jr, D
# AB    :  237
# OBP   :  .313
# SLG   :  .464
# OPS   :  .777
# ------------------------
# Player:  Ozuna, M
# AB    :  285
# OBP   :  .324
# SLG   :  .512
# OPS   :  .836
# ------------------------
# Player:  Goldschmidt, P
# AB    :  289
# OBP   :  .345
# SLG   :  .426
# OPS   :  .770
# ------------------------
# Player:  McCutchen, A
# AB    :  219
# OBP   :  .378
# SLG   :  .457
# OPS   :  .834
# ------------------------
# Player:  Gonzalez, M
# AB    :  231
# OBP   :  .323
# SLG   :  .420
# OPS   :  .743
# ------------------------
# Player:  Anderson, B
# AB    :  284
# OBP   :  .337
# SLG   :  .415
# OPS   :  .753
# ------------------------
# Player:  Cain, L
# AB    :  300
# OBP   :  .314
# SLG   :  .357
# OPS   :  .671
# ------------------------
# Player:  Winker, J
# AB    :  226
# OBP   :  .335
# SLG   :  .465
# OPS   :  .799
# ------------------------
# Player:  Renfroe, H
# AB    :  227
# OBP   :  .312
# SLG   :  .617
# OPS   :  .929
# ------------------------
# Player:  Vogelbach, D
# AB    :  235
# OBP   :  .388
# SLG   :  .523
# OPS   :  .912
# ------------------------
# Player:  Harper, B
# AB    :  287
# OBP   :  .365
# SLG   :  .467
# OPS   :  .832
# ------------------------
# Player:  Davis, K
# AB    :  246
# OBP   :  .310
# SLG   :  .463
# OPS   :  .773
# ------------------------
# Player:  Kiermaier, K
# AB    :  246
# OBP   :  .298
# SLG   :  .427
# OPS   :  .725
# ------------------------
# Player:  Kipnis, J
# AB    :  222
# OBP   :  .305
# SLG   :  .387
# OPS   :  .692
# ------------------------
# Player:  Sanchez, Y
# AB    :  210
# OBP   :  .323
# SLG   :  .305
# OPS   :  .628
# ------------------------
# Player:  Villar, J
# AB    :  299
# OBP   :  .310
# SLG   :  .405
# OPS   :  .715
# ------------------------
# Player:  Adames, W
# AB    :  255
# OBP   :  .314
# SLG   :  .376
# OPS   :  .691
# ------------------------
# Player:  Suarez, E
# AB    :  281
# OBP   :  .323
# SLG   :  .463
# OPS   :  .786
# ------------------------
# Player:  Reyes, F
# AB    :  233
# OBP   :  .297
# SLG   :  .532
# OPS   :  .829
# ------------------------
# Player:  Piscotty, S
# AB    :  284
# OBP   :  .304
# SLG   :  .398
# OPS   :  .702
# ------------------------
# Player:  Robles, V
# AB    :  248
# OBP   :  .315
# SLG   :  .435
# OPS   :  .751
# ------------------------
# Player:  Wong, K
# AB    :  248
# OBP   :  .330
# SLG   :  .379
# OPS   :  .709
# ------------------------
# Player:  Pillar, K
# AB    :  277
# OBP   :  .267
# SLG   :  .404
# OPS   :  .671
# ------------------------
# Player:  Goodrum, N
# AB    :  249
# OBP   :  .320
# SLG   :  .402
# OPS   :  .722
# ------------------------
# Player:  Arcia, O
# AB    :  266
# OBP   :  .302
# SLG   :  .398
# OPS   :  .701
# ------------------------
# Player:  Fowler, D
# AB    :  208
# OBP   :  .346
# SLG   :  .399
# OPS   :  .745
# ------------------------
# Player:  Puig, Y
# AB    :  267
# OBP   :  .286
# SLG   :  .461
# OPS   :  .746
# ------------------------
# Player:  Soler, J
# AB    :  293
# OBP   :  .306
# SLG   :  .512
# OPS   :  .818
# ------------------------
# Player:  Castro, S
# AB    :  302
# OBP   :  .268
# SLG   :  .321
# OPS   :  .589
# ------------------------
# Player:  Pujols, A
# AB    :  232
# OBP   :  .309
# SLG   :  .448
# OPS   :  .758
# ------------------------
# Player:  Dozier, B
# AB    :  234
# OBP   :  .318
# SLG   :  .436
# OPS   :  .754
# ------------------------
# Player:  Smith, M
# AB    :  239
# OBP   :  .306
# SLG   :  .364
# OPS   :  .670
# ------------------------
# Player:  Duggar, S
# AB    :  248
# OBP   :  .277
# SLG   :  .343
# OPS   :  .620
# ------------------------
# Player:  Gardner, B
# AB    :  248
# OBP   :  .317
# SLG   :  .440
# OPS   :  .756
# ------------------------
# Player:  Nunez, R
# AB    :  270
# OBP   :  .291
# SLG   :  .463
# OPS   :  .754
# ------------------------
# Player:  Panik, J
# AB    :  249
# OBP   :  .314
# SLG   :  .321
# OPS   :  .636
# ------------------------
# Player:  Pederson, J
# AB    :  215
# OBP   :  .328
# SLG   :  .558
# OPS   :  .886
# ------------------------
# Player:  Calhoun, K
# AB    :  271
# OBP   :  .325
# SLG   :  .469
# OPS   :  .793
# ------------------------
# Player:  Bruce, J
# AB    :  224
# OBP   :  .291
# SLG   :  .571
# OPS   :  .863
# ------------------------
# Player:  Schwarber, K
# AB    :  259
# OBP   :  .322
# SLG   :  .467
# OPS   :  .789
# ------------------------
# Player:  Cabrera, A
# AB    :  247
# OBP   :  .312
# SLG   :  .409
# OPS   :  .721
# ------------------------
# Player:  Belt, B
# AB    :  230
# OBP   :  .358
# SLG   :  .426
# OPS   :  .785
# ------------------------
# Player:  Tellez, R
# AB    :  226
# OBP   :  .287
# SLG   :  .465
# OPS   :  .752
# ------------------------
# Player:  Longoria, E
# AB    :  231
# OBP   :  .309
# SLG   :  .390
# OPS   :  .698
# ------------------------
# Player:  Encarnacion, E
# AB    :  267
# OBP   :  .343
# SLG   :  .513
# OPS   :  .856
# ------------------------
# Player:  Grichuk, R
# AB    :  299
# OBP   :  .284
# SLG   :  .418
# OPS   :  .702
# ------------------------
# Player:  Smoak, J
# AB    :  213
# OBP   :  .364
# SLG   :  .423
# OPS   :  .787
# ------------------------
# Player:  Bauers, J
# AB    :  245
# OBP   :  .302
# SLG   :  .384
# OPS   :  .685
# ------------------------
# Player:  Haniger, M
# AB    :  246
# OBP   :  .314
# SLG   :  .463
# OPS   :  .778
# ------------------------
# Player:  Myers, W
# AB    :  237
# OBP   :  .315
# SLG   :  .401
# OPS   :  .716
# ------------------------
# Player:  Profar, J
# AB    :  269
# OBP   :  .280
# SLG   :  .383
# OPS   :  .663
# ------------------------
# Player:  Bradley Jr., J
# AB    :  238
# OBP   :  .322
# SLG   :  .391
# OPS   :  .713
# ------------------------
# Player:  Carpenter, M
# AB    :  271
# OBP   :  .329
# SLG   :  .380
# OPS   :  .709
# ------------------------
# Player:  Ramirez, J
# AB    :  286
# OBP   :  .308
# SLG   :  .332
# OPS   :  .640
# ------------------------
# Player:  Franco, M
# AB    :  229
# OBP   :  .285
# SLG   :  .389
# OPS   :  .673
# ------------------------
# Player:  Crawford, B
# AB    :  248
# OBP   :  .280
# SLG   :  .331
# OPS   :  .611
# ------------------------
# Player:  Hernandez, K
# AB    :  245
# OBP   :  .282
# SLG   :  .388
# OPS   :  .670
# ------------------------
# Player:  Martin, L
# AB    :  236
# OBP   :  .276
# SLG   :  .343
# OPS   :  .619
# ------------------------
# Player:  Alonso, Y
# AB    :  218
# OBP   :  .276
# SLG   :  .303
# OPS   :  .579
# ------------------------
# Player:  Odor, R
# AB    :  234
# OBP   :  .249
# SLG   :  .350
# OPS   :  .599
# ------------------------

# %%
# 建立DataFrame
players_dataframe = pd.DataFrame()

# %%
# 將各個list放入dataframe對應項目
players_dataframe['Player'] = player_list
players_dataframe['AB'] = ab_list
players_dataframe['OBP'] = obp_list
players_dataframe['SLG'] = slg_list
players_dataframe['OPS'] = ops_list

# %%
# checkpoint
# 查看當前dataframe狀況
players_dataframe
# Out:
#              Player   AB   OBP   SLG    OPS
# 0      Bellinger, C  272  .444  .699  1.143
# 1         Yelich, C  266  .435  .744  1.179
# 2         McNeil, J  242  .403  .488   .891
# 3       LeMahieu, D  293  .380  .495   .875
# 4       Blackmon, C  269  .376  .643  1.019
# 5        Polanco, J  301  .383  .542   .925
# 6        Arenado, N  296  .386  .588   .973
# 7       Brantley, M  295  .382  .512   .893
# 8           Dahl, D  254  .370  .524   .894
# 9        Freeman, F  308  .402  .601  1.003
# 10          Bell, J  289  .386  .640  1.026
# 11      Anderson, T  268  .338  .485   .823
# 12        Rendon, A  232  .404  .634  1.038
# 13         Marte, K  307  .359  .586   .946
# 14        Devers, R  302  .362  .503   .865
# 15         Trout, M  257  .466  .642  1.108
# 16          Soto, J  249  .399  .534   .933
# 17       Mancini, T  282  .364  .564   .928
# 18       Meadows, A  230  .377  .552   .930
# 19        Andrus, E  280  .340  .464   .804
# 20    Merrifield, W  330  .350  .506   .856
# 21       Verdugo, A  225  .352  .489   .841
# 22        Turner, J  253  .380  .435   .815
# 23       Moncada, Y  274  .352  .522   .874
# 24     La Stella, T  259  .350  .498   .848
# 25       Reddick, J  263  .337  .441   .778
# 26      Bogaerts, X  297  .388  .529   .917
# 27       Cabrera, M  247  .359  .389   .747
# 28     Contreras, W  221  .388  .561   .949
# 29      Iglesias, J  238  .333  .420   .754
# ..              ...  ...   ...   ...    ...
# 131       Dozier, B  234  .318  .436   .754
# 132        Smith, M  239  .306  .364   .670
# 133       Duggar, S  248  .277  .343   .620
# 134      Gardner, B  248  .317  .440   .756
# 135        Nunez, R  270  .291  .463   .754
# 136        Panik, J  249  .314  .321   .636
# 137     Pederson, J  215  .328  .558   .886
# 138      Calhoun, K  271  .325  .469   .793
# 139        Bruce, J  224  .291  .571   .863
# 140    Schwarber, K  259  .322  .467   .789
# 141      Cabrera, A  247  .312  .409   .721
# 142         Belt, B  230  .358  .426   .785
# 143       Tellez, R  226  .287  .465   .752
# 144     Longoria, E  231  .309  .390   .698
# 145  Encarnacion, E  267  .343  .513   .856
# 146      Grichuk, R  299  .284  .418   .702
# 147        Smoak, J  213  .364  .423   .787
# 148       Bauers, J  245  .302  .384   .685
# 149      Haniger, M  246  .314  .463   .778
# 150        Myers, W  237  .315  .401   .716
# 151       Profar, J  269  .280  .383   .663
# 152  Bradley Jr., J  238  .322  .391   .713
# 153    Carpenter, M  271  .329  .380   .709
# 154      Ramirez, J  286  .308  .332   .640
# 155       Franco, M  229  .285  .389   .673
# 156     Crawford, B  248  .280  .331   .611
# 157    Hernandez, K  245  .282  .388   .670
# 158       Martin, L  236  .276  .343   .619
# 159       Alonso, Y  218  .276  .303   .579
# 160         Odor, R  234  .249  .350   .599
#
# [161 rows x 5 columns]
